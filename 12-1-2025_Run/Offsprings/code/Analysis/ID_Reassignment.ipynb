# %%
import pandas as pd

# %%
import yaml

# Path to your YAML file
file_path = "/net/vast-storage.ib.cluster/scratch/vast/lhtsai/rraju/data/moseq_data/moseq2-index.yaml"

# Open and load the YAML file
with open(file_path, "r") as f:
    data = yaml.safe_load(f)

# Inspect the contents
#print(data)

# If you want a prettier view
import pprint
pprint.pprint(data)
# Out:
# {'files': [{'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Mom1_030624',
#                          'StartTime': '2024-03-06T11:41:43.2004382-05:00',
#                          'SubjectName': 'Mom1_LNB'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-06_11-41-43_mom1_030624_mom1_lnb_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-06_11-41-43_mom1_030624_mom1_lnb_results_00.yaml'],
#             'uuid': '9c7c5d54-67eb-49d4-aeb0-2039b53102a1'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Mom3_030724',
#                          'StartTime': '2024-03-07T10:50:23.5551401-05:00',
#                          'SubjectName': 'Mom3_NGH'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_10-50-23_mom3_030724_mom3_ngh_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_10-50-23_mom3_030724_mom3_ngh_results_00.yaml'],
#             'uuid': '01b7b197-f8e9-4cc8-934a-9652d1746229'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Mom4_030724',
#                          'StartTime': '2024-03-07T11:44:20.7810082-05:00',
#                          'SubjectName': 'Mom4_LNB'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_11-44-20_mom4_030724_mom4_lnb_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_11-44-20_mom4_030724_mom4_lnb_results_00.yaml'],
#             'uuid': '50fd9290-c498-4ca2-9929-49a38b6c8ffb'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Mom2_030724',
#                          'StartTime': '2024-03-07T12:39:45.8207186-05:00',
#                          'SubjectName': 'Mom2_LNB'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_12-39-45_mom2_030724_mom2_lnb_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_12-39-45_mom2_030724_mom2_lnb_results_00.yaml'],
#             'uuid': '12fc2b40-79c3-45fc-862d-3a4a770676bd'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Mom5_030824',
#                          'StartTime': '2024-03-08T10:46:27.3544295-05:00',
#                          'SubjectName': 'Mom5_NGH'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-08_10-46-27_mom5_030824_mom5_ngh_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-08_10-46-27_mom5_030824_mom5_ngh_results_00.yaml'],
#             'uuid': '0650491b-b1e2-4672-8db2-b9fd33212de2'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 1_NGH1_M1_032124',
#                          'StartTime': '2024-03-21T12:06:51.5522096-04:00',
#                          'SubjectName': 'Trial 1_NGH1_M1_032124'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_12-06-51_trial-1_ngh1_m1_032124_trial-1_ngh1_m1_032124_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_12-06-51_trial-1_ngh1_m1_032124_trial-1_ngh1_m1_032124_results_00.yaml'],
#             'uuid': '6d2aed1d-69c8-4215-812d-51df9073e425'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 2_NGH1_M2_032124',
#                          'StartTime': '2024-03-21T12:37:13.4181157-04:00',
#                          'SubjectName': 'Trial 2_NGH1_M2_032124'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_12-37-13_trial-2_ngh1_m2_032124_trial-2_ngh1_m2_032124_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_12-37-13_trial-2_ngh1_m2_032124_trial-2_ngh1_m2_032124_results_00.yaml'],
#             'uuid': '08ea2581-7375-45f7-824a-1e7c8d8f50b6'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 4_NGH1_M4_032124',
#                          'StartTime': '2024-03-21T13:37:12.8100821-04:00',
#                          'SubjectName': 'Trial 4_NGH1_M4_032124'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_13-37-12_trial-4_ngh1_m4_032124_trial-4_ngh1_m4_032124_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_13-37-12_trial-4_ngh1_m4_032124_trial-4_ngh1_m4_032124_results_00.yaml'],
#             'uuid': '1971b4ba-17b7-4cd2-9140-ac6764594309'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial
},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 30_SI16_F_032324',
#                          'StartTime': '2024-03-23T16:37:57.1145831-04:00',
#                          'SubjectName': 'Trial 30_SI16_F_032324'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_16-37-57_trial-30_si16_f_032324_trial-30_si16_f_032324_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_16-37-57_trial-30_si16_f_032324_trial-30_si16_f_032324_results_00.yaml'],
#             'uuid': 'a71a98ab-8182-4852-8151-d1ba36f8cf27'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 31_SI4_F_032324',
#                          'StartTime': '2024-03-23T17:05:59.9298743-04:00',
#                          'SubjectName': 'Trial 31_SI4_F_032324'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_17-05-59_trial-31_si4_f_032324_trial-31_si4_f_032324_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_17-05-59_trial-31_si4_f_032324_trial-31_si4_f_032324_results_00.yaml'],
#             'uuid': 'a30fb574-449d-4915-906f-7d97736a92de'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 32_SI6_F_032324',
#                          'StartTime': '2024-03-23T17:34:40.8827272-04:00',
#                          'SubjectName': 'Trial 32_SI6_F_032324'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_17-34-40_trial-32_si6_f_032324_trial-32_si6_f_032324_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_17-34-40_trial-32_si6_f_032324_trial-32_si6_f_032324_results_00.yaml'],
#             'uuid': 'b6c441b5-6062-4444-a143-f3aaf113d739'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 33_SI8_F_032424',
#                          'StartTime': '2024-03-24T12:36:44.3185271-04:00',
#                          'SubjectName': 'Trial 33_SI8_F_032424'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_12-36-44_trial-33_si8_f_032424_trial-33_si8_f_032424_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_12-36-44_trial-33_si8_f_032424_trial-33_si8_f_032424_results_00.yaml'],
#             'uuid': 'eee24124-bdd3-44d0-9797-636fb7bed03e'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 34_SI10_F_032424',
#                          'StartTime': '2024-03-24T13:04:58.7307905-04:00',
#                          'SubjectName': 'Trial 34_SI10_F_032424'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_13-04-58_trial-34_si10_f_032424_trial-34_si10_f_032424_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_13-04-58_trial-34_si10_f_032424_trial-34_si10_f_032424_results_00.yaml'],
#             'uuid': 'fdaf439d-d48c-4885-b40d-926a976c2845'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 35_SI12_F_032424',
#                          'StartTime': '2024-03-24T13:32:52.9936423-04:00',
#                          'SubjectName': 'Trial 35_SI12_F_032424'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_13-32-52_trial-35_si12_f_032424_trial-35_si12_f_032424_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_13-32-52_trial-35_si12_f_032424_trial-35_si12_f_032424_results_00.yaml'],
#             'uuid': '829b976c-5480-4d98-b16b-a56aaea5e590'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 36_SI14_F_032424',
#                          'StartTime': '2024-03-24T14:01:30.1963143-04:00',
#                          'SubjectName': 'Trial 36_SI14_F_032424'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_14-01-30_trial-36_si14_f_032424_trial-36_si14_f_032424_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_14-01-30_trial-36_si14_f_032424_trial-36_si14_f_032424_results_00.yaml'],
#             'uuid': '76b54d0a-7ae8-483e-8aaa-b026fdb59181'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 37_EE4_F1_032424',
#                          'StartTime': '2024-03-24T14:38:02.2782679-04:00',
#                          'SubjectName': 'Trial 37_EE4_F1_032424'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_14-38-02_trial-37_ee4_f1_032424_trial-37_ee4_f1_032424_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_14-38-02_trial-37_ee4_f1_032424_trial-37_ee4_f1_032424_results_00.yaml'],
#             'uuid': 'fa6c56cd-5f15-49be-be66-27f74516248b'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'Trial 38_EE4_F2_032424',
#                          'StartTime': '2024-03-24T15:07:54.9419728-04:00',
#                          'SubjectName': 'Trial 38_EE4_F2_032424'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24
050224_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_12-25-55_ngh3_f1_050224_ngh3_f1_050224_results_00.yaml'],
#             'uuid': '0ac4d258-d416-4cc2-aa36-6b6cb3aa3eb7'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'NGH3_F2_050224',
#                          'StartTime': '2024-05-02T12:53:41.3486205-04:00',
#                          'SubjectName': 'NGH3_F2_050224'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_12-53-41_ngh3_f2_050224_ngh3_f2_050224_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_12-53-41_ngh3_f2_050224_ngh3_f2_050224_results_00.yaml'],
#             'uuid': '4b441fc3-69d5-47e2-91c4-6493cc5572e2'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'NGH3_F3_050224',
#                          'StartTime': '2024-05-02T13:21:42.7610356-04:00',
#                          'SubjectName': 'NGH3_F3_050224'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_13-21-42_ngh3_f3_050224_ngh3_f3_050224_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_13-21-42_ngh3_f3_050224_ngh3_f3_050224_results_00.yaml'],
#             'uuid': '3c54b708-a854-49aa-8f95-69211ab22894'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'NGH3_F4_050224',
#                          'StartTime': '2024-05-02T13:50:20.6648129-04:00',
#                          'SubjectName': 'NGH3_F4_050224'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_13-50-20_ngh3_f4_050224_ngh3_f4_050224_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_13-50-20_ngh3_f4_050224_ngh3_f4_050224_results_00.yaml'],
#             'uuid': '991f984b-f03f-452f-a1ca-781f1f8a5c6a'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'LNB3_F1_050224',
#                          'StartTime': '2024-05-02T14:27:38.1534471-04:00',
#                          'SubjectName': 'LNB3_F1_050224'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_14-27-38_lnb3_f1_050224_lnb3_f1_050224_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_14-27-38_lnb3_f1_050224_lnb3_f1_050224_results_00.yaml'],
#             'uuid': '4da51d6c-9298-442c-94f2-497e531ca636'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'LNB3_F2_050224',
#                          'StartTime': '2024-05-02T14:56:19.2617926-04:00',
#                          'SubjectName': 'LNB3_F2_050224'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_14-56-19_lnb3_f2_050224_lnb3_f2_050224_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_14-56-19_lnb3_f2_050224_lnb3_f2_050224_results_00.yaml'],
#             'uuid': '7c74a5b5-3c3d-4d84-86d4-871ccbba7892'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'LNB3_F3_050224',
#                          'StartTime': '2024-05-02T15:24:26.7132283-04:00',
#                          'SubjectName': 'LNB3_F3_050224'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_15-24-26_lnb3_f3_050224_lnb3_f3_050224_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_15-24-26_lnb3_f3_050224_lnb3_f3_050224_results_00.yaml'],
#             'uuid': '7335756b-0a6a-4e0e-be48-fdaff2f5989c'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'NGH4_F1_050224',
#                          'StartTime': '2024-05-02T15:54:38.681164-04:00',
#                          'SubjectName': 'NGH4_F1_050224'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_15-54-38_ngh4_f1_050224_ngh4_f1_050224_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_15-54-38_ngh4_f1_050224_ngh4_f1_050224_results_00.yaml'],
#             'uuid': '150f5f17-19fe-444e-9d17-2cf2af6df208'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'NGH4_F2_050224',
#                          'StartTime': '2024-05-02T16:24:34.1051189-04:00',
#                          'SubjectName': 'NGH4_F2_050224'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-24-34_ngh4_f2_050224_ngh4_f2_050224_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-24-34_ngh4_f2_050224_ngh4_f2_050224_results_00.yaml'],
#             'uuid': 'dbe1d424-5821-49c5-8547-51b2c3209361'},
#            {'group': 'default',
#             'metadata': {'ColorDataType': 'Byte[]',
#                          'ColorResolution': [512, 424],
#                          'DepthDataType': 'UInt16[]',
#                          'DepthResolution': [512, 424],
#                          'IsLittleEndian': True,
#                          'NidaqChannels': 0,
#                          'NidaqSamplingRate': 0.0,
#                          'SessionName': 'NGH4_F3_050224',
#                          'StartTime': '2024-05-02T16:54:44.1131268-04:00',
#                          'SubjectName': 'NGH4_F3_050224'},
#             'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-54-44_ngh4_f3_050224_ngh4_f3_050224_results_00.h5',
#                      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-54-44_ngh4_f3_050224_ngh4_f3_050224_results_00.yaml'],
#             'uuid': 'b95d5b66-ed2e-41c4-aed8-05be3991b357'}],
#  'pca_path': ''}

# %%
import os, json, re
from pathlib import Path
from dateutil import parser as dtparser

MOSEQ_BASE = Path("/om2/user/rraju/data/moseq_data")

# ---- index the session_* dirs on disk
session_rows = []
for sdir in MOSEQ_BASE.iterdir():
    if sdir.is_dir() and sdir.name.startswith("session_"):
        meta_path = sdir / "metadata.json"
        meta = {}
        if meta_path.exists():
            try:
                meta = json.loads(meta_path.read_text())
            except Exception:
                pass
        session_rows.append({
            "moseq_id": sdir.name,  # e.g., session_20240306113848
            "disk_SessionName": meta.get("SessionName"),
            "disk_SubjectName": meta.get("SubjectName"),
            "disk_StartTime": meta.get("StartTime"),
        })

sessions_df = pd.DataFrame(session_rows)

# ---- extract from YAML (uuid, SessionName, StartTime, and a timestamp from path)
def path_to_digits(paths):
    if not paths: return None
    m = re.search(r'(\d{4}-\d{2}-\d{2})_(\d{2}-\d{2}-\d{2})', " ".join(paths))
    if not m: return None
    return (m.group(1)+m.group(2)).replace("-", "")  # YYYYMMDDHHMMSS

def iso_to_digits(s):
    if not s: return None
    try:
        return dtparser.isoparse(s).strftime("%Y%m%d%H%M%S")
    except Exception:
        return None

yaml_rows = []
for f in data.get("files", []):
    meta = f.get("metadata", {}) or {}
    dig_from_path = path_to_digits(f.get("path", []))
    dig_from_iso  = iso_to_digits(meta.get("StartTime"))
    yaml_rows.append({
        "yaml_uuid": f.get("uuid"),
        "yaml_SessionName": meta.get("SessionName"),
        "yaml_SubjectName": meta.get("SubjectName"),
        "yaml_StartTime": meta.get("StartTime"),
        "ts_digits_from_path": dig_from_path,
        "ts_digits_from_iso": dig_from_iso,
    })

yaml_df = pd.DataFrame(yaml_rows)

# sessions_df also needs a ts_digits to align by time
def disk_iso_to_digits(s):
    if not s: return None
    try:
        return dtparser.isoparse(s).strftime("%Y%m%d%H%M%S")
    except Exception:
        return None

sessions_df["ts_digits_disk"] = sessions_df["disk_StartTime"].map(disk_iso_to_digits)

# ---- 3 passes to connect YAML -> session_*
# A) by timestamp from YAML path
m_by_path = yaml_df.merge(
    sessions_df, left_on="ts_digits_from_path", right_on="ts_digits_disk", how="left"
)

# B) fill remaining by StartTime ISO
mask_unmatched = m_by_path["moseq_id"].isna()
m_by_iso = m_by_path.loc[mask_unmatched].drop(columns=["moseq_id","disk_SessionName","disk_SubjectName","disk_StartTime","ts_digits_disk"]).merge(
    sessions_df, left_on="ts_digits_from_iso", right_on="ts_digits_disk", how="left"
)
m_by_path.loc[mask_unmatched, ["moseq_id","disk_SessionName","disk_SubjectName","disk_StartTime","ts_digits_disk"]] = \
    m_by_iso[["moseq_id","disk_SessionName","disk_SubjectName","disk_StartTime","ts_digits_disk"]].values

# C) fill remaining by SessionName exact
mask_unmatched = m_by_path["moseq_id"].isna() & m_by_path["yaml_SessionName"].notna()
m_by_name = m_by_path.loc[mask_unmatched].drop(columns=["moseq_id","disk_SessionName","disk_SubjectName","disk_StartTime","ts_digits_disk"]).merge(
    sessions_df, left_on="yaml_SessionName", right_on="disk_SessionName", how="left"
)
m_by_path.loc[mask_unmatched, ["moseq_id","disk_SessionName","disk_SubjectName","disk_StartTime","ts_digits_disk"]] = \
    m_by_name[["moseq_id","disk_SessionName","disk_SubjectName","disk_StartTime","ts_digits_disk"]].values

# This is our YAML→MoSeq lookup
yaml_to_moseq = m_by_path[[
    "yaml_uuid", "yaml_SessionName", "yaml_SubjectName", "yaml_StartTime", "moseq_id"
]].rename(columns={"yaml_uuid":"uuid"})
print("Built YAML→MoSeq table. Rows:", len(yaml_to_moseq))
print("Matched sessions:", yaml_to_moseq['moseq_id'].notna().sum())
# Out:
# Built YAML→MoSeq table. Rows: 76
# Matched sessions: 76

# %%
moseq_df = pd.read_csv('../../data/moseq_df.csv')

# %% [markdown]
# # Males

# %%
males_df = pd.read_csv('../../data/analysis_output/constructed_fingerprints/Males/offspring_PCA25_embedding.csv.gz')

# %%
males_df
# Out:
#                                     uuid category        PC1        PC2  \
# 0   b337bf67-7270-42f5-8b72-78dd050c5145      LNB -10.488839  -3.002693
# 1   744530d8-f277-48b3-8627-39c69e04bcde      LNB   6.768376  -6.057944
# 2   5083529c-320b-4bea-9ceb-d119b2594f13      NGH  -4.023883  -4.397324
# 3   6c06a0b7-7ca1-45ef-bb49-6a4589681bf4      NGH   1.565465  -0.103222
# 4   72b39b1e-5973-43e2-bedb-0f00ace4848b      NGH  -4.905071   4.324940
# 5   be2c69ec-d004-4d52-b844-13e9634737ed       SI  -4.389551  -1.807877
# 6   8425e949-99ab-4e71-baf9-5e653eb68223      NGH   0.503875  -3.760428
# 7   e235873b-f363-4a61-8a8c-3e935da3ed3d      LNB   1.223713  -5.039052
# 8   a30299ff-63d0-4c08-9b26-0cc143eef34b      LNB   8.607919  -1.724041
# 9   774ba130-08f1-45ee-9c61-636e6de87827       SI -13.315558  -6.063129
# 10  37e31c07-bedb-4afd-a128-9e8eea3e6ed6       EE  11.358688  -1.318797
# 11  967cea17-5b5e-4166-b0da-81fa56b8ad1a       SI  -8.978220   6.319145
# 12  50da788c-2302-41e3-bd7a-8e92b3e24d95       EE  23.170748   6.638115
# 13  a9a43e79-be6d-43f9-afcc-684fd0bdeafc       SI  -1.715169   4.922559
# 14  9af80187-1f8b-4a78-bdf6-9cdcaea7c7a8       EE   7.423226   1.347147
# 15  2a84130d-6477-4fcc-a644-eb0527024917      NGH   2.086985  -1.455639
# 16  3ac8d60e-8a2c-4244-9761-658ef5682856      LNB  -0.519020 -12.114787
# 17  d5fe97bf-c8c6-4400-bd91-1a355888d818       SI  -3.384283  -1.459206
# 18  92b48143-ece8-4749-aff3-73be8f258ece       EE   8.298043  11.807014
# 19  474ec161-b087-432a-a167-97147a282508       SI  -7.684316  -4.201004
# 20  35e3c7fa-074d-4714-8f40-df91701e6507      NGH  -0.771613  -1.342382
# 21  3f11e55d-f6ca-4f1e-889b-194e312985a1      LNB  -5.336033  -7.604247
# 22  0e7e9b38-4cb6-400c-b0f5-6e4034920500       EE  11.970040  -1.123180
# 28 -1.398054  0.667373 -4.405123  0.008528  3.984557 -3.072950 -3.704110
# 29  3.117041 -1.350285 -0.703388 -1.303191 -2.650908 -1.281028  3.324093
# 30  2.148478 -0.416171  4.079441 -1.898594  3.534269 -0.020264 -1.215347
# 31 -5.702750  0.703756 -0.172945  2.881554  2.121607  0.410574  1.502224
# 32  0.702234  1.488489  1.441522  2.300238  1.180126  1.042860  5.586407
#
#         PC23      PC24      PC25
# 0  -3.200069  0.518018  1.143666
# 1  -0.044093 -2.469546 -0.191657
# 2   4.016852  2.676931  1.084237
# 3  -2.875565 -0.031040 -3.489109
# 4   1.378117  0.613474  1.505021
# 5   0.329716  0.156254  0.606976
# 6  -1.359058 -2.269827  7.296103
# 7  -1.464470  1.651568 -1.986215
# 8   0.370215  1.550691  0.353148
# 9   1.170640 -3.714841 -2.219023
# 10 -1.740678 -3.214973 -1.855369
# 11 -1.133116  2.508527 -0.337957
# 12  0.560986 -0.645147  0.216448
# 13 -1.510453 -1.093667  0.629411
# 14  0.609777  1.692262  1.688363
# 15 -4.801927 -0.078378  2.174755
# 16 -0.525129  0.207496 -0.292860
# 17 -0.746591  0.503098 -1.329001
# 18  2.599427  0.052614 -1.021547
# 19  0.805814 -0.180237 -1.121931
# 20 -3.640967  1.080395 -0.796130
# 21 -1.053951 -2.261023 -1.460987
# 22  1.319580  0.038121  3.182102
# 23  1.278284  1.729729 -0.868297
# 24 -0.883881 -0.103883 -0.977220
# 25  0.394566 -3.641262  2.866953
# 26  1.218579 -0.104670 -0.203875
# 27  6.621200 -0.258197 -0.516277
# 28 -1.519545  3.643564 -2.591354
# 29  0.268946  1.502792  0.204096
# 30  1.132393 -4.367685 -2.278189
# 31  0.272877  4.663840  1.608720
# 32  2.151524 -0.355000 -1.023002
#
# [33 rows x 27 columns]

# %%
from pathlib import Path
import json
import pandas as pd
from dateutil import parser as dtparser

MOSEQ_BASE = Path("/om2/user/rraju/data/moseq_data")

# ── 1) Build SessionName -> session_* (dedup to one per name, pick latest by StartTime)
rows = []
for sdir in MOSEQ_BASE.iterdir():
    if sdir.is_dir() and sdir.name.startswith("session_"):
        meta_path = sdir / "metadata.json"
        if not meta_path.exists():
            continue
        try:
            meta = json.loads(meta_path.read_text())
        except Exception:
            continue
        sess_name = meta.get("SessionName")
        start_iso = meta.get("StartTime")
        try:
            start_dt = dtparser.isoparse(start_iso) if start_iso else None
        except Exception:
            start_dt = None
        if sess_name:
            rows.append({
                "SessionName": sess_name,
                "moseq_id": sdir.name,
                "Start_dt": start_dt,
            })

sessions_df = pd.DataFrame(rows)
if sessions_df.empty:
    raise RuntimeError("No session_* metadata found under MOSEQ_BASE")

# Normalize SessionName to avoid tiny formatting mismatches
sessions_df["SessionName_norm"] = sessions_df["SessionName"].str.strip().str.lower()

# For duplicate names, keep the latest by StartTime
sessions_df = (
    sessions_df.sort_values(["SessionName_norm","Start_dt"])
               .groupby("SessionName_norm", as_index=False)
               .tail(1)
               .loc[:, ["SessionName_norm","moseq_id"]]
)

# ── 2) Reduce moseq_df to ONE row per uuid -> SessionName (resolve duplicates)
# Keep only the two columns we need, drop exact dup rows, normalize names.
mmap = (moseq_df.loc[:, ["uuid","SessionName"]]
                 .dropna()
                 .drop_duplicates())
mmap["SessionName_norm"] = mmap["SessionName"].str.strip().str.lower()

# How many uuids map to >1 (normalized) names?
dup_counts = mmap.groupby("uuid")["SessionName_norm"].nunique()
conflict_uuids = dup_counts[dup_counts > 1].index.tolist()

if conflict_uuids:
    # Resolve conflicts by selecting the SessionName that actually exists on disk;
    # if multiple exist, prefer the one whose session_* is the latest (already encoded in sessions_df).
    candidates = (mmap[mmap["uuid"].isin(conflict_uuids)]
                    .merge(sessions_df, on="SessionName_norm", how="left"))

    # Rank: keep those that matched a session_*, drop non-matching; then pick one per uuid
    candidates["has_session"] = candidates["moseq_id"].notna()
    resolved = (candidates[candidates["has_session"]]
                .drop_duplicates(subset=["uuid","SessionName_norm"])
                .groupby("uuid", as_index=False)
                .first()[["uuid","SessionName_norm"]])

    # Replace conflicting uuids in mmap with the resolved pick
    keep_simple = mmap[~mmap["uuid"].isin(conflict_uuids)]
    mmap = pd.concat([keep_simple, resolved], ignore_index=True)

# Ensure one row per uuid now
assert mmap["uuid"].is_unique, "Still not one row per uuid after resolution."

# ── 3) Map uuid -> session_* via SessionName_norm
uuid_to_moseq = mmap.merge(sessions_df, on="SessionName_norm", how="left")[["uuid","moseq_id"]]

# Optional sanity checks
n_total = len(males_df)
n_have_uuid = males_df["uuid"].notna().sum()
n_resolvable = uuid_to_moseq["moseq_id"].notna().sum()
print(f"Unique uuid in mapping: {len(uuid_to_moseq)} (with moseq_id for {n_resolvable})")

# ── 4) Final one-to-one merge onto males_df (and validate)
# pandas validate raises if many-to-many would occur
result = males_df.merge(uuid_to_moseq, on="uuid", how="left", validate="one_to_one")

print(f"Rows in males_df: {n_total}")
print(f"Mapped to session_*: {result['moseq_id'].notna().sum()}/{n_total}")

# Show any that failed to map
if result["moseq_id"].isna().any():
    print("\nUnmapped uuids (head):")
    print(result.loc[result["moseq_id"].isna(), "uuid"].head())
# Out:
# Unique uuid in mapping: 65 (with moseq_id for 65)
# Rows in males_df: 33
# Mapped to session_*: 33/33

# %%
result
# Out:
#                                     uuid category        PC1        PC2  \
# 0   b337bf67-7270-42f5-8b72-78dd050c5145      LNB -10.488839  -3.002693
# 1   744530d8-f277-48b3-8627-39c69e04bcde      LNB   6.768376  -6.057944
# 2   5083529c-320b-4bea-9ceb-d119b2594f13      NGH  -4.023883  -4.397324
# 3   6c06a0b7-7ca1-45ef-bb49-6a4589681bf4      NGH   1.565465  -0.103222
# 4   72b39b1e-5973-43e2-bedb-0f00ace4848b      NGH  -4.905071   4.324940
# 5   be2c69ec-d004-4d52-b844-13e9634737ed       SI  -4.389551  -1.807877
# 6   8425e949-99ab-4e71-baf9-5e653eb68223      NGH   0.503875  -3.760428
# 7   e235873b-f363-4a61-8a8c-3e935da3ed3d      LNB   1.223713  -5.039052
# 28  3.643564 -2.591354  session_20240501170444
# 29  1.502792  0.204096  session_20240322164811
# 30 -4.367685 -2.278189  session_20240321123527
# 31  4.663840  1.608720  session_20240501120816
# 32 -0.355000 -1.023002  session_20240501113736
#
# [33 rows x 28 columns]

# %%
result.to_csv('../../data/analysis_output/constructed_fingerprints/Males/final_data/males_final_data.csv')

# %% [markdown]
# # Females

# %%
males_df = pd.read_csv('../../data/analysis_output/constructed_fingerprints/Females/offspring_PCA25_embedding.csv.gz')

# %%
from pathlib import Path
import json
import pandas as pd
from dateutil import parser as dtparser

MOSEQ_BASE = Path("/om2/user/rraju/data/moseq_data")

# ── 1) Build SessionName -> session_* (dedup to one per name, pick latest by StartTime)
rows = []
for sdir in MOSEQ_BASE.iterdir():
    if sdir.is_dir() and sdir.name.startswith("session_"):
        meta_path = sdir / "metadata.json"
        if not meta_path.exists():
            continue
        try:
            meta = json.loads(meta_path.read_text())
        except Exception:
            continue
        sess_name = meta.get("SessionName")
        start_iso = meta.get("StartTime")
        try:
            start_dt = dtparser.isoparse(start_iso) if start_iso else None
        except Exception:
            start_dt = None
        if sess_name:
            rows.append({
                "SessionName": sess_name,
                "moseq_id": sdir.name,
                "Start_dt": start_dt,
            })

sessions_df = pd.DataFrame(rows)
if sessions_df.empty:
    raise RuntimeError("No session_* metadata found under MOSEQ_BASE")

# Normalize SessionName to avoid tiny formatting mismatches
sessions_df["SessionName_norm"] = sessions_df["SessionName"].str.strip().str.lower()

# For duplicate names, keep the latest by StartTime
sessions_df = (
    sessions_df.sort_values(["SessionName_norm","Start_dt"])
               .groupby("SessionName_norm", as_index=False)
               .tail(1)
               .loc[:, ["SessionName_norm","moseq_id"]]
)

# ── 2) Reduce moseq_df to ONE row per uuid -> SessionName (resolve duplicates)
# Keep only the two columns we need, drop exact dup rows, normalize names.
mmap = (moseq_df.loc[:, ["uuid","SessionName"]]
                 .dropna()
                 .drop_duplicates())
mmap["SessionName_norm"] = mmap["SessionName"].str.strip().str.lower()

# How many uuids map to >1 (normalized) names?
dup_counts = mmap.groupby("uuid")["SessionName_norm"].nunique()
conflict_uuids = dup_counts[dup_counts > 1].index.tolist()

if conflict_uuids:
    # Resolve conflicts by selecting the SessionName that actually exists on disk;
    # if multiple exist, prefer the one whose session_* is the latest (already encoded in sessions_df).
    candidates = (mmap[mmap["uuid"].isin(conflict_uuids)]
                    .merge(sessions_df, on="SessionName_norm", how="left"))

    # Rank: keep those that matched a session_*, drop non-matching; then pick one per uuid
    candidates["has_session"] = candidates["moseq_id"].notna()
    resolved = (candidates[candidates["has_session"]]
                .drop_duplicates(subset=["uuid","SessionName_norm"])
                .groupby("uuid", as_index=False)
                .first()[["uuid","SessionName_norm"]])

    # Replace conflicting uuids in mmap with the resolved pick
    keep_simple = mmap[~mmap["uuid"].isin(conflict_uuids)]
    mmap = pd.concat([keep_simple, resolved], ignore_index=True)

# Ensure one row per uuid now
assert mmap["uuid"].is_unique, "Still not one row per uuid after resolution."

# ── 3) Map uuid -> session_* via SessionName_norm
uuid_to_moseq = mmap.merge(sessions_df, on="SessionName_norm", how="left")[["uuid","moseq_id"]]

# Optional sanity checks
n_total = len(males_df)
n_have_uuid = males_df["uuid"].notna().sum()
n_resolvable = uuid_to_moseq["moseq_id"].notna().sum()
print(f"Unique uuid in mapping: {len(uuid_to_moseq)} (with moseq_id for {n_resolvable})")

# ── 4) Final one-to-one merge onto males_df (and validate)
# pandas validate raises if many-to-many would occur
result = males_df.merge(uuid_to_moseq, on="uuid", how="left", validate="one_to_one")

print(f"Rows in males_df: {n_total}")
print(f"Mapped to session_*: {result['moseq_id'].notna().sum()}/{n_total}")

# Show any that failed to map
if result["moseq_id"].isna().any():
    print("\nUnmapped uuids (head):")
    print(result.loc[result["moseq_id"].isna(), "uuid"].head())
# Out:
# Unique uuid in mapping: 65 (with moseq_id for 65)
# Rows in males_df: 33
# Mapped to session_*: 33/33

# %%
result
# Out:
#                                     uuid category        PC1        PC2  \
# 0   add943f9-2caf-47ff-80d1-b825d3419b37      NGH  -1.481707  24.608028
# 1   6271b7ca-21da-475e-aa9a-021f3fbfe725      NGH   1.161096  -6.299882
# 2   d5fe97bf-c8c6-4400-bd91-1a355888d818       SI  -3.384283  -1.459206
# 3   f32cc80e-36a8-4cf6-823e-478f8eb4af38      NGH   2.422226  -2.227157
# 4   3ac8d60e-8a2c-4244-9761-658ef5682856      LNB  -0.519020 -12.114787
# 5   2a84130d-6477-4fcc-a644-eb0527024917      NGH   2.086985  -1.455639
# 6   9af80187-1f8b-4a78-bdf6-9cdcaea7c7a8       EE   7.423226   1.347147
# 7   774ba130-08f1-45ee-9c61-636e6de87827       SI -13.315558  -6.063129
# 8   3f11e55d-f6ca-4f1e-889b-194e312985a1      LNB  -5.336033  -7.604247
# 9   5083529c-320b-4bea-9ceb-d119b2594f13      NGH  -4.023883  -4.397324
# 10  f08e41bb-6bea-49fc-888a-8cd26c465dbd      NGH   4.159352  -8.198228
# 11  6c06a0b7-7ca1-45ef-bb49-6a4589681bf4      NGH   1.565465  -0.103222
# 12  523977de-8784-4c6e-9d0a-9a8b3a13c38b      LNB  -4.874566  -3.622566
# 13  11466614-49c8-4388-91ad-736d6b050085      NGH  -8.641415  10.018568
# 14  92b48143-ece8-4749-aff3-73be8f258ece       EE   8.298043  11.807014
# 15  72b39b1e-5973-43e2-bedb-0f00ace4848b      NGH  -4.905071   4.324940
# 16  a86b803c-1a4e-45a7-94c5-86b76707b217      NGH  -9.493776   5.591257
# 17  dbdc0682-0cc4-47f8-bd56-031dd6739b00       SI -17.217041   6.134775
# 18  744530d8-f277-48b3-8627-39c69e04bcde      LNB   6.768376  -6.057944
# 19  a9a43e79-be6d-43f9-afcc-684fd0bdeafc       SI  -1.715169   4.922559
# 20  474ec161-b087-432a-a167-97147a282508       SI  -7.684316  -4.201004
# 21  a30299ff-63d0-4c08-9b26-0cc143eef34b      LNB   8.607919  -1.724041
# 22  e235873b-f363-4a61-8a8c-3e935da3ed3d      LNB   1.223713  -5.039052
# 28 -3.507169  0.769946 -3.977353  6.809349 -1.668795  0.369935  1.319580
# 29  2.238599  2.632133  2.707013 -5.200101 -3.108255 -1.301416  1.278284
# 30 -0.416171  4.079441 -1.898594  3.534269 -0.020264 -1.215347  1.132393
# 31 -1.905248 -0.991918 -2.423897 -0.658960  3.193661 -0.797051 -1.740678
# 32  1.784934 -0.383128  0.778776 -2.166860 -0.189151  0.754519  0.560986
#
#         PC24      PC25                moseq_id
# 0  -0.103883 -0.977220  session_20240321133542
# 1   4.663840  1.608720  session_20240501120816
# 2   0.503098 -1.329001  session_20240322121426
# 3   3.643564 -2.591354  session_20240501170444
# 4   0.207496 -0.292860  session_20240501131605
# 5  -0.078378  2.174755  session_20240322155235
# 6   1.692262  1.688363  session_20240321143422
# 7  -3.714841 -2.219023  session_20240321170920
# 8  -2.261023 -1.460987  session_20240501134504
# 9   2.676931  1.084237  session_20240501173310
# 10 -0.355000 -1.023002  session_20240501113736
# 11 -0.031040 -3.489109  session_20240501123937
# 12 -0.258197 -0.516277  session_20240501153756
# 13  1.502792  0.204096  session_20240322164811
# 14  0.052614 -1.021547  session_20240322145105
# 15  0.613474  1.505021  session_20240322161944
# 16 -3.641262  2.866953  session_20240321120441
# 17 -0.104670 -0.203875  session_20240322130809
# 18 -2.469546 -0.191657  session_20240501150902
# 19 -1.093667  0.629411  session_20240321173727
# 20 -0.180237 -1.121931  session_20240322124015
# 21  1.550691  0.353148  session_20240501144135
# 22  1.651568 -1.986215  session_20240501160602
# 23 -2.269827  7.296103  session_20240501110509
# 24  2.508527 -0.337957  session_20240322133649
# 25  0.156254  0.606976  session_20240321164046
# 26  0.518018  1.143666  session_20240501141330
# 27  1.080395 -0.796130  session_20240501163548
# 28  0.038121  3.182102  session_20240322151854
# 29  1.729729 -0.868297  session_20240322141530
# 30 -4.367685 -2.278189  session_20240321123527
# 31 -3.214973 -1.855369  session_20240321140505
# 32 -0.645147  0.216448  session_20240321160846
#
# [33 rows x 28 columns]

# %%
result.to_csv('../../data/analysis_output/constructed_fingerprints/Females/final_data/females_final_data.csv')

# %% [markdown]
# # Moms

# %%
males_df = pd.read_csv('../../data/analysis_output/constructed_fingerprints/Moms/offspring_PCA8_embedding.csv.gz')

# %%
from pathlib import Path
import json
import pandas as pd
from dateutil import parser as dtparser

MOSEQ_BASE = Path("/om2/user/rraju/data/moseq_data")

# ── 1) Build SessionName -> session_* (dedup to one per name, pick latest by StartTime)
rows = []
for sdir in MOSEQ_BASE.iterdir():
    if sdir.is_dir() and sdir.name.startswith("session_"):
        meta_path = sdir / "metadata.json"
        if not meta_path.exists():
            continue
        try:
            meta = json.loads(meta_path.read_text())
        except Exception:
            continue
        sess_name = meta.get("SessionName")
        start_iso = meta.get("StartTime")
        try:
            start_dt = dtparser.isoparse(start_iso) if start_iso else None
        except Exception:
            start_dt = None
        if sess_name:
            rows.append({
                "SessionName": sess_name,
                "moseq_id": sdir.name,
                "Start_dt": start_dt,
            })

sessions_df = pd.DataFrame(rows)
if sessions_df.empty:
    raise RuntimeError("No session_* metadata found under MOSEQ_BASE")

# Normalize SessionName to avoid tiny formatting mismatches
sessions_df["SessionName_norm"] = sessions_df["SessionName"].str.strip().str.lower()

# For duplicate names, keep the latest by StartTime
sessions_df = (
    sessions_df.sort_values(["SessionName_norm","Start_dt"])
               .groupby("SessionName_norm", as_index=False)
               .tail(1)
               .loc[:, ["SessionName_norm","moseq_id"]]
)

# ── 2) Reduce moseq_df to ONE row per uuid -> SessionName (resolve duplicates)
# Keep only the two columns we need, drop exact dup rows, normalize names.
mmap = (moseq_df.loc[:, ["uuid","SessionName"]]
                 .dropna()
                 .drop_duplicates())
mmap["SessionName_norm"] = mmap["SessionName"].str.strip().str.lower()

# How many uuids map to >1 (normalized) names?
dup_counts = mmap.groupby("uuid")["SessionName_norm"].nunique()
conflict_uuids = dup_counts[dup_counts > 1].index.tolist()

if conflict_uuids:
    # Resolve conflicts by selecting the SessionName that actually exists on disk;
    # if multiple exist, prefer the one whose session_* is the latest (already encoded in sessions_df).
    candidates = (mmap[mmap["uuid"].isin(conflict_uuids)]
                    .merge(sessions_df, on="SessionName_norm", how="left"))

    # Rank: keep those that matched a session_*, drop non-matching; then pick one per uuid
    candidates["has_session"] = candidates["moseq_id"].notna()
    resolved = (candidates[candidates["has_session"]]
                .drop_duplicates(subset=["uuid","SessionName_norm"])
                .groupby("uuid", as_index=False)
                .first()[["uuid","SessionName_norm"]])

    # Replace conflicting uuids in mmap with the resolved pick
    keep_simple = mmap[~mmap["uuid"].isin(conflict_uuids)]
    mmap = pd.concat([keep_simple, resolved], ignore_index=True)

# Ensure one row per uuid now
assert mmap["uuid"].is_unique, "Still not one row per uuid after resolution."

# ── 3) Map uuid -> session_* via SessionName_norm
uuid_to_moseq = mmap.merge(sessions_df, on="SessionName_norm", how="left")[["uuid","moseq_id"]]

# Optional sanity checks
n_total = len(males_df)
n_have_uuid = males_df["uuid"].notna().sum()
n_resolvable = uuid_to_moseq["moseq_id"].notna().sum()
print(f"Unique uuid in mapping: {len(uuid_to_moseq)} (with moseq_id for {n_resolvable})")

# ── 4) Final one-to-one merge onto males_df (and validate)
# pandas validate raises if many-to-many would occur
result = males_df.merge(uuid_to_moseq, on="uuid", how="left", validate="one_to_one")

print(f"Rows in males_df: {n_total}")
print(f"Mapped to session_*: {result['moseq_id'].notna().sum()}/{n_total}")

# Show any that failed to map
if result["moseq_id"].isna().any():
    print("\nUnmapped uuids (head):")
    print(result.loc[result["moseq_id"].isna(), "uuid"].head())
# Out:
# Unique uuid in mapping: 65 (with moseq_id for 65)
# Rows in males_df: 11
# Mapped to session_*: 0/11
#
# Unmapped uuids (head):
# 0    9f45197b-4e21-4ee3-9e84-3fde2831d7d4
# 1    d58916e7-fff3-4763-8ac0-8637f3fe512f
# 2    365247e5-d810-4242-87f4-1c144f1a211f
# 3    06f178be-3ba4-4c4b-b795-05703f6a3e0e
# 4    0c39c4f8-ffce-4ba9-b5c0-6fa221762363
# Name: uuid, dtype: object
