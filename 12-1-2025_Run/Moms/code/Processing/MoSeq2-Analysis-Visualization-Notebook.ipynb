# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Project-setup" data-toc-modified-id="Project-setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Project setup</a></span><ul class="toc-item"><li><span><a href="#Files-and-Directory-Structure" data-toc-modified-id="Files-and-Directory-Structure-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Files and Directory Structure</a></span></li><li><span><a href="#Load-Progress" data-toc-modified-id="Load-Progress-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Load Progress</a></span></li><li><span><a href="#Setup-Directory-Structure-for-Analyzing-Model(s)" data-toc-modified-id="Setup-Directory-Structure-for-Analyzing-Model(s)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Setup Directory Structure for Analyzing Model(s)</a></span></li><li><span><a href="#[OPTIONAL]-Override-Paths-to-Specific-Model" data-toc-modified-id="[OPTIONAL]-Override-Paths-to-Specific-Model-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>[OPTIONAL] Override Paths to Specific Model</a></span></li></ul></li><li><span><a href="#Compute-Syllable-Statistics" data-toc-modified-id="Compute-Syllable-Statistics-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Compute Syllable Statistics</a></span><ul class="toc-item"><li><span><a href="#Compute-moseq_df" data-toc-modified-id="Compute-moseq_df-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Compute <code>moseq_df</code></a></span></li><li><span><a href="#Export-moseq_df" data-toc-modified-id="Export-moseq_df-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Export <code>moseq_df</code></a></span></li><li><span><a href="#Compute-stats_df" data-toc-modified-id="Compute-stats_df-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Compute <code>stats_df</code></a></span></li><li><span><a href="#Export-stats_df" data-toc-modified-id="Export-stats_df-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Export <code>stats_df</code></a></span></li><li><span><a href="#Generate-Behavioral-Summary-(Fingerprints)" data-toc-modified-id="Generate-Behavioral-Summary-(Fingerprints)-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Generate Behavioral Summary (Fingerprints)</a></span></li></ul></li><li><span><a href="#Crowd-Movie-Generation-and-Interactive-Syllable-Labelling-Tool" data-toc-modified-id="Crowd-Movie-Generation-and-Interactive-Syllable-Labelling-Tool-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Crowd Movie Generation and Interactive Syllable Labelling Tool</a></span></li><li><span><a href="#Generate-Syllable-Dendrogram" data-toc-modified-id="Generate-Syllable-Dendrogram-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Generate Syllable Dendrogram</a></span></li><li><span><a href="#Interactive-Syllable-Statistics-Graphing" data-toc-modified-id="Interactive-Syllable-Statistics-Graphing-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Interactive Syllable Statistics Graphing</a></span></li><li><span><a href="#Compute-Syllable-Transition-Matrices" data-toc-modified-id="Compute-Syllable-Transition-Matrices-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Compute Syllable Transition Matrices</a></span><ul class="toc-item"><li><span><a href="#Export-Transition-Matrices-and-Usages" data-toc-modified-id="Export-Transition-Matrices-and-Usages-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Export Transition Matrices and Usages</a></span></li><li><span><a href="#Interactive-Syllable-Transition-Graph-Tool" data-toc-modified-id="Interactive-Syllable-Transition-Graph-Tool-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Interactive Syllable Transition Graph Tool</a></span></li></ul></li><li><span><a href="#Notebook-End" data-toc-modified-id="Notebook-End-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Notebook End</a></span></li><li><span><a href="#User-Survey" data-toc-modified-id="User-Survey-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>User Survey</a></span></li></ul></div>

# %% [markdown]
# # Introduction
# <img src="https://drive.google.com/uc?export=view&id=1oc0_0mlN0VTZEPMQTg_hnYAC87Lb58MI">
#
# **Welcome to MoSeq2 Analysis Visualization Notebook!**
#
# This notebook contains a collection of analyses we typically perform on behavioral recordings to better understand mouse behavior. Examples of such analyses are:
# - descriptive labeling of individual syllables
# - comparing syllable usage across different experimental groups
# - comparing syllable transition structure across different experimental groups
#
# The goal of this notebook is to provide you with a basic summary of syllable usage and sequencing statistics across experimental conditions and to help generate more specific questions related to observations you may identify here.
# If you want to perform more specific analyses, you can export the MoSeq data (see below) to use with the tool (i.e., Excel, Python, R, Matlab) you're most comfortable with.
#
# In this notebook, the **Markdown** above each cell describes the purpose of the cell(s), cell output, and the instructions for running the cell(s) and/or interacting with the widget. The **inline code comments** in the code block provides contextual information about the function, code structure, and parameters.
#
# ***

# %% [markdown]
# # Project setup
#
# ## Files and Directory Structure
# To run this notebook, you need the following files and folders in your data directory:
# - `progress.yaml` - this file stores all the required MoSeq paths used throughout the notebooks
# - `config.yaml` - configuration file that stores parameters used throughout the MoSeq pipeline
# - `aggregate_results/` - folder that contains aggregated and extracted session data
# - `moseq2-index.yaml` - contains paths to extracted sessions and is used to generate syllable crowd movies
# - `_pca/` - folder that contains data generated from the PCA section of the extraction notebook or CLI
# - `base_model_path` - the folder that keeps all the trained models or all the output model objects after applying pre-trained model(s) to data.
# - `model.p` - the trained AR-HMM or the output model object after applying a pre-trained model. There should be at least one trained AR-HMM or one output applied model object in the `base_model_path`.
#
# At this stage, your base directory should look something like what's shown below:
# ```
# .
# └── <data_dir>/
#     ├── config.yaml
#     ├── aggregate_results/
#     ├── moseq2-index.yaml
#     ├── _pca/
#     ├── base_model_path/
#     ├   └── model.p
#     ...
#     └── progress.yaml
#
# ```
# For more information about how MoSeq organizes data, check out our [wiki](https://github.com/dattalab/moseq2-app/wiki/Directory-Structures-and-yaml-Files-in-MoSeq-Pipeline).
#
# **Note: this notebook uses the `progress.yaml` file to keep track of all the necessary paths.** Please ensure you run the Load Progress cell below before running any analysis modules.

# %% [markdown]
# ## Load Progress
#
# **[IMPORTANT] ALWAYS run this cell when you open this notebook.** If you don't, the analysis functions won't work.
#
# MoSeq uses a [progress.yaml](https://github.com/dattalab/moseq2-app/wiki/Directory-Structures-and-yaml-Files-in-MoSeq-Pipeline#progressyaml) file to keep track of the progress.
#
# The following cell generates a `progress.yaml` file or loads your progress from the last saved checkpoint.  This cell checks if the `progress_paths` dictionary contains the necessary paths to use the features in the rest of the notebook and displays the content in `progress_paths`.
#
# - **Specify the path to the `progress.yaml` file**. No change is needed if the notebooks are in the base directory.
# - **Run the following cell**.
#
# **Note:** If the Extraction, PCA, and/or modeling steps are done using the Command Line Interface, set `from_CLI=True`.

# %%
from os.path import join, dirname, abspath
from moseq2_app.gui.progress import update_progress, restore_progress_vars, progress_path_sanity_check

progress_filepath = './progress.yaml' # Add the path to your progress.yaml here.

# set to True if you are coming from the CLI and did not use the extraction and modeling notebook.
# keep False if you came from the extraction and modeling notebook. Most users will keep this False
from_CLI = False
# keep False if this is not a model object from applying a pre-trained model to new data. Most users will keep this False
pretrained_model_used = False

progress_paths = restore_progress_vars(progress_file=progress_filepath, init=from_CLI, overwrite=False)


print(f'BASE DIR: ' + progress_paths['base_dir'])
# Find the best model when coming from extraction and modeling from the CLI.
if from_CLI and not pretrained_model_used:
    # Find the best model given the objective
    from moseq2_viz.gui import get_best_fit_model
    output_file = join(progress_paths['base_dir'], 'model_vs_pc_changepoints')
    objective = 'median_loglikelihood'  # objective could be either duration, jsd or median_loglikelihood
    best_model_fit = get_best_fit_model(progress_paths, output_file, plot_all=True, objective=objective)
    progress_paths = update_progress(progress_filepath, 'model_path', best_model_fit[f'best model - {objective}'])

progress_path_sanity_check(progress_paths, progress_filepath) # check all necessary paths exist

progress_paths
# Out:
# Updating notebook variables...
# BASE DIR: /om2/user/rraju/data/moseq_data
# Please check and correct the path in base_dir. The default path should contain /net/vast-storage.ib.cluster/scratch/vast/lhtsai/rraju/data/moseq_data
# File names are not default values, please check if this is intentional
# ====================
# Please check and correct the path in scores_filename. The default path should contain pca_scores
# File names are not default values, please check if this is intentional
# ====================
# {'base_dir': '/om2/user/rraju/data/moseq_data',
#  'config_file': '/om2/user/rraju/data/moseq_data/config.yaml',
#  'session_config': '/om2/user/rraju/data/moseq_data/session_config.yaml',
#  'index_file': '/om2/user/rraju/data/moseq_data/moseq2-index.yaml',
#  'train_data_dir': '/om2/user/rraju/data/moseq_data/aggregate_results/',
#  'pca_dirname': '/om2/user/rraju/data/moseq_data/_pca/',
#  'scores_filename': '',
#  'scores_path': '/om2/user/rraju/data/moseq_data/_pca/pca_scores.h5',
#  'changepoints_path': 'changepoints',
#  'model_path': '/om2/user/rraju/data/moseq_data/models/model-007-12915497/model-007-12915497.p',
#  'crowd_dir': '/om2/user/rraju/data/moseq_data/models/model-007-12915497/crowd_movies/',
#  'syll_info': '/om2/user/rraju/data/moseq_data/models/model-007-12915497/syll_info.yaml',
#  'plot_path': '/om2/user/rraju/data/moseq_data/models/model-007-12915497/plots/',
#  'snapshot': '1874f14c-d124-4035-990a-d482b737341e',
#  'base_model_path': '/om2/user/rraju/data/moseq_data/models/',
#  'model_session_path': '/om2/user/rraju/data/moseq_data/models/model-007-12915497',
#  'df_info_path': '/om2/user/rraju/data/moseq_data/models/model-007-12915497/syll_df.parquet'}

# %% [markdown]
# ## Setup Directory Structure for Analyzing Model(s)
# This step reorganizes trained models so that they have their own folder, which makes it easy to associate the analyses below with specific models (the analyses are saved in the same folder as the model).
#
# The following step creates a folder for each model and copies the model to the respective folder.
# Refer to the [wiki](https://github.com/dattalab/moseq2-app/wiki/Directory-Structures-and-yaml-Files-in-MoSeq-Pipeline#after-training-the-ar-hmm-models) for more details about how this step reorganizes models.
#
# - **Run the following cell**.

# %%
from moseq2_app.util import setup_model_folders, update_model_paths
from os.path import basename

best_model = basename(progress_paths['model_path'])

model_dict = setup_model_folders(progress_paths)
progress_paths = update_model_paths(best_model, model_dict, progress_filepath)
# Out:
# Variables are the same. No update necessary.
# Variables are the same. No update necessary.
# Variables are the same. No update necessary.
# Variables are the same. No update necessary.
# Variables are the same. No update necessary.
# Variables are the same. No update necessary.

# %% [markdown]
# ## [OPTIONAL] Override Paths to Specific Model
# NOTE: only run this section if you want to skip finding the best model and manually select a model to analyze.
#
# **Instructions:**
# - **Specify the file name of the model in the `desired_model` field.** The model name must be a key of the `model_dict` dictionary.
# - **Run the following cell**.

# %%
from moseq2_app.util import update_model_paths
print('Select a model from the following models:', [key for key in model_dict.keys()])
desired_model = best_model # override this with the file name to the desired model, eg. "model1.p"

# Update progress file
progress_paths = update_model_paths(desired_model, model_dict, progress_filepath)

# %% [markdown]
# # Compute Syllable Statistics
# MoSeq extracts scalar values (eg. 2D velocity, width, height, etc) from the depth video while the models identify behavioral motifs (syllables).
# The steps below combine these data streams into a `DataFrame`. Learn more about `DataFrames` on [pandas's website](https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html).
#
# `DataFrames` are both useful for the analysis and visualization cells below, and are a great way to organize data.
# This means you can save and export them in multiple formats to run custom analyses in the software of your choosing.
# You can find more information about how we use `DataFrames` in the wiki [here](https://github.com/dattalab/moseq2-app/wiki/MoSeq2-Analysis-Visualization-Notebook-Instructions#compute-syllable-statistics).

# %% [markdown]
# ## Compute `moseq_df`
# The following cell generates a `DataFrame` of scalar values computed during the extraction step aligned to the model labels. All sessions are concatenated to form this `DataFrame`. Each row is one "frame" which corresponds to one sample from the original depth video. Each column is a different entry.
# To view the entries of this `DataFrame`, run `print(moseq_df.columns)`. This `DataFrame` can be used to plot the scalar feature values for any session over time.
# [Visit our wiki](https://github.com/dattalab/moseq2-app/wiki/MoSeq2-Analysis-Visualization-Notebook-Instructions#moseq_df) for more information about the contents of each column.
#
# You will notice multiple columns with syllable labels. Two of the columns relabels syllables by "usage" or "frames". [See here](https://github.com/dattalab/moseq2-app/wiki/MoSeq2-Analysis-Visualization-Notebook-Instructions#sorting-syllable-labels) for information about how this relabeling is performed.
#
# **Note:** the rows in the `labels` columns contain `-5` for the first 3 frames of each session's recordings.
# This is because we use the first 3 frames to initialize the AR-HMM (`nlags = 3` in the modeling step), and thus cannot give a label to them.
# We generally remove these frames from analysis.
#
# **Instructions:**
# - **Run the following cell**.

# %%
'/om2/user/rraju/data/moseq_data/_pca/pca_scores.h5'

# %%
#import pyyaml
progress_paths['index_file']
# Out:
# '/om2/user/rraju/data/moseq_data/moseq2-index.yaml'

# %%
from moseq2_viz.util import parse_index
from moseq2_viz.scalars.util import scalars_to_dataframe

_, sorted_index = parse_index(progress_paths['index_file'])
sorted_index['pca_path'] = '/om2/user/rraju/data/moseq_data/_pca/pca_scores.h5'
#del sorted_index['files']['cf3f996b-e103-464f-b132-cfeeeb9e61ed']
# compute session scalar data
moseq_df = scalars_to_dataframe(sorted_index, model_path=progress_paths['model_path'])

print('moseq_df size: ', moseq_df.shape[0], 'rows;', moseq_df.shape[1], 'columns')

# this line prints out the first 5 rows of the dataframe in table format. It is used to
# get a sense of what is contained in the DataFrame
moseq_df.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Creating MoSeq DataFrame', max=76.0, style=ProgressStyle(…
# moseq_df size:  2732911 rows; 33 columns
#    labels (original)  labels (usage sort)  labels (frames sort)  onset  \
# 0                 -5                   -5                    -5   True
# 1                 -5                   -5                    -5  False
# 2                 -5                   -5                    -5  False
# 3                 11                   28                    20   True
# 4                 11                   28                    20  False
#
#    frame index  syllable index       kappa               model_type     angle  \
# 0          0.0               0  12915497.0  ARWeakLimitStickyHDPHMM  0.182306
# 1          1.0               1  12915497.0  ARWeakLimitStickyHDPHMM  0.148898
# 2          2.0               2  12915497.0  ARWeakLimitStickyHDPHMM  0.108350
# 3          3.0               3  12915497.0  ARWeakLimitStickyHDPHMM  0.072249
# 4          4.0               4  12915497.0  ARWeakLimitStickyHDPHMM  0.058085
#
#        area_mm  ...   width_mm   width_px  dist_to_center_px    group  \
# 0  1208.119019  ...  29.730005  17.637337          84.321266  LNB_Mom
# 1  1211.447144  ...  29.377670  17.428314          85.519539  LNB_Mom
# 2  1211.447144  ...  28.711660  17.033201          86.049828  LNB_Mom
# 3  1218.103516  ...  28.217875  16.740265          86.481895  LNB_Mom
# 4  1204.790894  ...  28.811085  17.092186          86.164017  LNB_Mom
#
#                                    uuid  \
# 0  9c7c5d54-67eb-49d4-aeb0-2039b53102a1
# 1  9c7c5d54-67eb-49d4-aeb0-2039b53102a1
# 2  9c7c5d54-67eb-49d4-aeb0-2039b53102a1
# 3  9c7c5d54-67eb-49d4-aeb0-2039b53102a1
# 4  9c7c5d54-67eb-49d4-aeb0-2039b53102a1
#
#                                              h5_path    timestamps  \
# 0  /om2/user/rraju/data/moseq_data/aggregate_resu...  6.347277e+08
# 1  /om2/user/rraju/data/moseq_data/aggregate_resu...  6.347278e+08
# 2  /om2/user/rraju/data/moseq_data/aggregate_resu...  6.347278e+08
# 3  /om2/user/rraju/data/moseq_data/aggregate_resu...  6.347278e+08
# 4  /om2/user/rraju/data/moseq_data/aggregate_resu...  6.347279e+08
#
#    SessionName                          StartTime  SubjectName
# 0  Mom1_030624  2024-03-06T11:41:43.2004382-05:00     Mom1_LNB
# 1  Mom1_030624  2024-03-06T11:41:43.2004382-05:00     Mom1_LNB
# 2  Mom1_030624  2024-03-06T11:41:43.2004382-05:00     Mom1_LNB
# 3  Mom1_030624  2024-03-06T11:41:43.2004382-05:00     Mom1_LNB
# 4  Mom1_030624  2024-03-06T11:41:43.2004382-05:00     Mom1_LNB
#
# [5 rows x 33 columns]

# %%
parse_index(progress_paths['index_file'])
# Out:
# ({'files': [{'filename': '2024-03-06_11-41-43_mom1_030624_mom1_lnb_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Mom1_030624',
#      'StartTime': '2024-03-06T11:41:43.2004382-05:00',
#      'SubjectName': 'Mom1_LNB'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-06_11-41-43_mom1_030624_mom1_lnb_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-06_11-41-43_mom1_030624_mom1_lnb_results_00.yaml'],
#     'uuid': '36924daa-7b3f-4fbb-a1fc-46d2c28fb505'},
#    {'filename': '2024-03-07_10-50-23_mom3_030724_mom3_ngh_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Mom3_030724',
#      'StartTime': '2024-03-07T10:50:23.5551401-05:00',
#      'SubjectName': 'Mom3_NGH'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_10-50-23_mom3_030724_mom3_ngh_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_10-50-23_mom3_030724_mom3_ngh_results_00.yaml'],
#     'uuid': '156dc2ef-544c-41e0-ae8a-45ca5f39fbdb'},
#    {'filename': '2024-03-07_11-44-20_mom4_030724_mom4_lnb_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Mom4_030724',
#      'StartTime': '2024-03-07T11:44:20.7810082-05:00',
#      'SubjectName': 'Mom4_LNB'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_11-44-20_mom4_030724_mom4_lnb_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_11-44-20_mom4_030724_mom4_lnb_results_00.yaml'],
#     'uuid': '5e985ff0-2f88-4193-bb49-7bc4256e0228'},
#    {'filename': '2024-03-07_12-39-45_mom2_030724_mom2_lnb_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Mom2_030724',
#      'StartTime': '2024-03-07T12:39:45.8207186-05:00',
#      'SubjectName': 'Mom2_LNB'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_12-39-45_mom2_030724_mom2_lnb_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-07_12-39-45_mom2_030724_mom2_lnb_results_00.yaml'],
#     'uuid': '4c5ecb1f-c9dc-48e5-89f1-03d88beceddd'},
#    {'filename': '2024-03-08_10-46-27_mom5_030824_mom5_ngh_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Mom5_030824',
#      'StartTime': '2024-03-08T10:46:27.3544295-05:00',
#      'SubjectName': 'Mom5_NGH'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-08_10-46-27_mom5_030824_mom5_ngh_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-08_10-46-27_mom5_030824_mom5_ngh_results_00.yaml'],
#     'uuid': '45c06e3e-4c2e-4fa7-b8c8-11e9d9b20616'},
#    {'filename': '2024-03-21_12-06-51_trial-1_ngh1_m1_032124_trial-1_ngh1_m1_032124_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 1_NGH1_M1_032124',
#      'StartTime': '2024-03-21T12:06:51.5522096-04:00',
#      'SubjectName': 'Trial 1_NGH1_M1_032124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_12-06-51_trial-1_ngh1_m1_032124_trial-1_ngh1_m1_032124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_12-06-51_trial-1_ngh1_m1_032124_trial-1_ngh1_m1_032124_results_00.yaml'],
#     'uuid': '52219521-6c81-4cb1-83b8-1a91b652e2ed'},
#    {'filename': '2024-03-21_12-37-13_trial-2_ngh1_m2_032124_trial-2_ngh1_m2_032124_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 2_NGH1_M2_032124',
#      'StartTime': '2024-03-21T12:37:13.4181157-04:00',
#      'SubjectName': 'Trial 2_NGH1_M2_032124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_12-37-13_trial-2_ngh1_m2_032124_trial-2_ngh1_m2_032124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_12-37-13_trial-2_ngh1_m2_032124_trial-2_ngh1_m2_032124_results_00.yaml'],
#     'uuid': 'ded0375b-8f4a-40e6-a768-2b7fdcb340d0'},
#    {'filename': '2024-03-21_13-37-12_trial-4_ngh1_m4_032124_trial-4_ngh1_m4_032124_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 4_NGH1_M4_032124',
#      'StartTime': '2024-03-21T13:37:12.8100821-04:00',
#      'SubjectName': 'Trial 4_NGH1_M4_032124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_13-37-12_trial-4_ngh1_m4_032124_trial-4_ngh1_m4_032124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_13-37-12_trial-4_ngh1_m4_032124_trial-4_ngh1_m4_032124_results_00.yaml'],
#     'uuid': '9043b3df-a659-40a0-8a7f-00f40bf4211a'},
#    {'filename': '2024-03-21_14-08-17_trial-5_ee1_m1_032124_trial-5_ee1_m1_032124_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 5_EE1_M1_032124',
#      'StartTime': '2024-03-21T14:08:17.7540268-04:00',
#      'SubjectName': 'Trial 5_EE1_M1_032124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_14-08-17_trial-5_ee1_m1_032124_trial-5_ee1_m1_032124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_14-08-17_trial-5_ee1_m1_032124_trial-5_ee1_m1_032124_results_00.yaml'],
#     'uuid': '23aa4f10-384e-4dc0-a81a-2e9fa1567967'},
#    {'filename': '2024-03-21_14-36-46_trial-6_ee1_m2_032124_trial-6_ee1_m2_032124_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 6_EE1_M2_032124',
#      'StartTime': '2024-03-21T14:36:46.4190167-04:00',
#      'SubjectName': 'Trial 6_EE1_M2_032124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_14-36-46_trial-6_ee1_m2_032124_trial-6_ee1_m2_032124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_14-36-46_trial-6_ee1_m2_032124_trial-6_ee1_m2_032124_results_00.yaml'],
#     'uuid': 'd7430e64-b209-46e8-a3fe-1aa583ab8500'},
#    {'filename': '2024-03-21_16-10-17_trial-8_ee1_m4_032124_trial-8_ee1_m4_032124_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 8_EE1_M4_032124',
#      'StartTime': '2024-03-21T16:10:17.6416891-04:00',
#      'SubjectName': 'Trial 8_EE1_M4_032124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_16-10-17_trial-8_ee1_m4_032124_trial-8_ee1_m4_032124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_16-10-17_trial-8_ee1_m4_032124_trial-8_ee1_m4_032124_results_00.yaml'],
#     'uuid': '655004cd-f1c3-4141-b00a-5206b202aaf6'},
#    {'filename': '2024-03-21_16-40-47_trial-9_si5_m_032124_trial-9_si5_m_032124_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 9_SI5_M_032124',
#      'StartTime': '2024-03-21T16:40:47.6166789-04:00',
#      'SubjectName': 'Trial 9_SI5_M_032124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_16-40-47_trial-9_si5_m_032124_trial-9_si5_m_032124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_16-40-47_trial-9_si5_m_032124_trial-9_si5_m_032124_results_00.yaml'],
#     'uuid': '9a8900b5-34ab-48e7-9a17-d845b3590603'},
#    {'filename': '2024-03-21_17-11-42_trial-10_si1_m_032124_trial-10_si1_m_032124_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 10_SI1_M_032124',
#      'StartTime': '2024-03-21T17:11:42.3890109-04:00',
#      'SubjectName': 'Trial 10_SI1_M_032124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_17-11-42_trial-10_si1_m_032124_trial-10_si1_m_032124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_17-11-42_trial-10_si1_m_032124_trial-10_si1_m_032124_results_00.yaml'],
#     'uuid': '9d865df3-1e3b-4ba1-86d2-95c5abb87ddd'},
#    {'filename': '2024-03-21_17-40-16_trial-11_si3_m_032124_trial-11_si3_m_032124_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 11_SI3_M_032124',
#      'StartTime': '2024-03-21T17:40:16.538201-04:00',
#      'SubjectName': 'Trial 11_SI3_M_032124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_17-40-16_trial-11_si3_m_032124_trial-11_si3_m_032124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-21_17-40-16_trial-11_si3_m_032124_trial-11_si3_m_032124_results_00.yaml'],
#     'uuid': '58645376-1524-4e4b-8468-48010fbb9449'},
#    {'filename': '2024-03-22_12-14-29_trial-12_si7_m_032224_trial-12_si7_m_032224_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 12_SI7_M_032224',
#      'StartTime': '2024-03-22T12:14:29.1047692-04:00',
#      'SubjectName': 'Trial 12_SI7_M_032224'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_12-14-29_trial-12_si7_m_032224_trial-12_si7_m_032224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_12-14-29_trial-12_si7_m_032224_trial-12_si7_m_032224_results_00.yaml'],
#     'uuid': '07de674a-66b2-4780-9fb1-a71670d1942f'},
#    {'filename': '2024-03-22_12-43-09_trial-13_si9_m_032224_trial-13_si9_m_032224_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 13_SI9_M_032224',
#      'StartTime': '2024-03-22T12:43:09.8667233-04:00',
#      'SubjectName': 'Trial 13_SI9_M_032224'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_12-43-09_trial-13_si9_m_032224_trial-13_si9_m_032224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_12-43-09_trial-13_si9_m_032224_trial-13_si9_m_032224_results_00.yaml'],
#     'uuid': '16faf940-bd28-4fbf-8d0d-ca7ff1179a5c'},
#    {'filename': '2024-03-22_13-11-08_trial-14_si11_m_032224_trial-14_si11_m_032224_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 14_SI11_M_032224',
#      'StartTime': '2024-03-22T13:11:08.1038973-04:00',
#      'SubjectName': 'Trial 14_SI11_M_032224'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_13-11-08_trial-14_si11_m_032224_trial-14_si11_m_032224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_13-11-08_trial-14_si11_m_032224_trial-14_si11_m_032224_results_00.yaml'],
#     'uuid': '49440386-32e6-4e44-85b2-8f763f8e4b75'},
#    {'filename': '2024-03-22_13-39-46_trial-15_si13_m_032224_trial-15_si13_m_032224_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 15_SI13_M_032224',
#      'StartTime': '2024-03-22T13:39:46.8977537-04:00',
#      'SubjectName': 'Trial 15_SI13_M_032224'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_13-39-46_trial-15_si13_m_032224_trial-15_si13_m_032224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_13-39-46_trial-15_si13_m_032224_trial-15_si13_m_032224_results_00.yaml'],
#     'uuid': 'be735d30-b5d8-4dc7-8ac1-a27a5f37806e'},
#    {'filename': '2024-03-22_14-20-11_trial-16_ee3_m1_032224_trial-16_ee3_m1_032224_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 16_EE3_M1_032224',
#      'StartTime': '2024-03-22T14:20:11.8815756-04:00',
#      'SubjectName': 'Trial 16_EE3_M1_032224'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_14-20-11_trial-16_ee3_m1_032224_trial-16_ee3_m1_032224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_14-20-11_trial-16_ee3_m1_032224_trial-16_ee3_m1_032224_results_00.yaml'],
#     'uuid': '83a5c982-a430-420e-8cf9-5610c7eafc95'},
#    {'filename': '2024-03-22_14-52-33_trial-17_ee3_m2_032224_trial-17_ee3_m2_032224_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 17_EE3_M2_032224',
#      'StartTime': '2024-03-22T14:52:33.317833-04:00',
#      'SubjectName': 'Trial 17_EE3_M2_032224'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_14-52-33_trial-17_ee3_m2_032224_trial-17_ee3_m2_032224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_14-52-33_trial-17_ee3_m2_032224_trial-17_ee3_m2_032224_results_00.yaml'],
#     'uuid': 'fc16b879-a921-414b-b334-4e19859c7bfd'},
#    {'filename': '2024-03-22_15-22-05_trial-18_ee3_m3_032224_trial-18_ee3_m3_032224_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 18_EE3_M3_032224',
#      'StartTime': '2024-03-22T15:22:05.4497857-04:00',
#      'SubjectName': 'Trial 18_EE3_M3_032224'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_15-22-05_trial-18_ee3_m3_032224_trial-18_ee3_m3_032224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_15-22-05_trial-18_ee3_m3_032224_trial-18_ee3_m3_032224_results_00.yaml'],
#     'uuid': '5744c7c6-34a7-4e0e-8e60-524a85740ac0'},
#    {'filename': '2024-03-22_15-52-37_trial-19_ngh3_m1_032224_trial-19_ngh3_m1_032224_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 19_NGH3_M1_032224',
#      'StartTime': '2024-03-22T15:52:37.4392221-04:00',
#      'SubjectName': 'Trial 19_NGH3_M1_032224'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_15-52-37_trial-19_ngh3_m1_032224_trial-19_ngh3_m1_032224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_15-52-37_trial-19_ngh3_m1_032224_trial-19_ngh3_m1_032224_results_00.yaml'],
#     'uuid': '7c8116fe-4237-45a9-8873-be7eb6f07fa2'},
#    {'filename': '2024-03-22_16-22-32_trial-20_ngh3_m2_032224_trial-20_ngh3_m2_032224_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 20_NGH3_M2_032224',
#      'StartTime': '2024-03-22T16:22:32.6488763-04:00',
#      'SubjectName': 'Trial 20_NGH3_M2_032224'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_16-22-32_trial-20_ngh3_m2_032224_trial-20_ngh3_m2_032224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_16-22-32_trial-20_ngh3_m2_032224_trial-20_ngh3_m2_032224_results_00.yaml'],
#     'uuid': 'e6fe570e-df9b-415e-ad27-373342f6ba24'},
#    {'filename': '2024-03-22_16-51-26_trial-21_ngh3_m3_032224_trial-21_ngh3_m3_032224_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 21_NGH3_M3_032224',
#      'StartTime': '2024-03-22T16:51:26.3854452-04:00',
#      'SubjectName': 'Trial 21_NGH3_M3_032224'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_16-51-26_trial-21_ngh3_m3_032224_trial-21_ngh3_m3_032224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-22_16-51-26_trial-21_ngh3_m3_032224_trial-21_ngh3_m3_032224_results_00.yaml'],
#     'uuid': 'e54dde9e-1253-4279-90e5-14d64bf90aae'},
#    {'filename': '2024-03-23_12-27-25_trial-22_ngh4_f1_032324_trial-22_ngh4_f1_032324_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 22_NGH4_F1_032324',
#      'StartTime': '2024-03-23T12:27:25.5711759-04:00',
#      'SubjectName': 'Trial 22_NGH4_F1_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_12-27-25_trial-22_ngh4_f1_032324_trial-22_ngh4_f1_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_12-27-25_trial-22_ngh4_f1_032324_trial-22_ngh4_f1_032324_results_00.yaml'],
#     'uuid': '35d5f450-ee20-47cf-b7f6-02bb25644d56'},
#    {'filename': '2024-03-23_12-56-01_trial-23_ngh4_f2_032324_trial-23_ngh4_f2_032324_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 23_NGH4_F2_032324',
#      'StartTime': '2024-03-23T12:56:01.8216209-04:00',
#      'SubjectName': 'Trial 23_NGH4_F2_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_12-56-01_trial-23_ngh4_f2_032324_trial-23_ngh4_f2_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_12-56-01_trial-23_ngh4_f2_032324_trial-23_ngh4_f2_032324_results_00.yaml'],
#     'uuid': '14be398f-ed85-4d44-ad0a-76313e68b69b'},
#    {'filename': '2024-03-23_13-30-46_trial-24_ee2_f1_032324_trial-24_ee2_f1_032324_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 24_EE2_F1_032324',
#      'StartTime': '2024-03-23T13:30:46.3874597-04:00',
#      'SubjectName': 'Trial 24_EE2_F1_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_13-30-46_trial-24_ee2_f1_032324_trial-24_ee2_f1_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_13-30-46_trial-24_ee2_f1_032324_trial-24_ee2_f1_032324_results_00.yaml'],
#     'uuid': 'e516c47a-1cef-46ad-be2b-d76c000e5622'},
#    {'filename': '2024-03-23_14-01-58_trial-25_ee2_f2_032324_trial-25_ee2_f2_032324_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 25_EE2_F2_032324',
#      'StartTime': '2024-03-23T14:01:58.9433329-04:00',
#      'SubjectName': 'Trial 25_EE2_F2_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_14-01-58_trial-25_ee2_f2_032324_trial-25_ee2_f2_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_14-01-58_trial-25_ee2_f2_032324_trial-25_ee2_f2_032324_results_00.yaml'],
#     'uuid': 'be42c701-1490-4533-a80b-6ce9e4623ef7'},
#    {'filename': '2024-03-23_14-30-59_trial-26_ee2_f3_032324_trial-26_ee2_f3_032324_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 26_EE2_F3_032324',
#      'StartTime': '2024-03-23T14:30:59.6636646-04:00',
#      'SubjectName': 'Trial 26_EE2_F3_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_14-30-59_trial-26_ee2_f3_032324_trial-26_ee2_f3_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_14-30-59_trial-26_ee2_f3_032324_trial-26_ee2_f3_032324_results_00.yaml'],
#     'uuid': 'b2be0886-0e2b-4c4c-a9f2-1c02f8d01287'},
#    {'filename': '2024-03-23_15-02-16_trial-27_ee2_f4_032324_trial-27_ee2_f4_032324_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 27_EE2_F4_032324',
#      'StartTime': '2024-03-23T15:02:16.2645374-04:00',
#      'SubjectName': 'Trial 27_EE2_F4_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_15-02-16_trial-27_ee2_f4_032324_trial-27_ee2_f4_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_15-02-16_trial-27_ee2_f4_032324_trial-27_ee2_f4_032324_results_00.yaml'],
#     'uuid': 'e6bed23a-05d4-470a-833f-cdabf6fdb229'},
#    {'filename': '2024-03-23_15-32-46_trial-28_ee2_f5_032324_trial-28_ee2_f5_032324_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 28_EE2_F5_032324',
#      'StartTime': '2024-03-23T15:32:46.0506335-04:00',
#      'SubjectName': 'Trial 28_EE2_F5_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_15-32-46_trial-28_ee2_f5_032324_trial-28_ee2_f5_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_15-32-46_trial-28_ee2_f5_032324_trial-28_ee2_f5_032324_results_00.yaml'],
#     'uuid': '83900c19-49de-4db1-a7c9-9ca32cac3683'},
#    {'filename': '2024-03-23_16-06-58_trial-29_si2_f_032324_trial-29_si2_f_032324_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 29_SI2_F_032324',
#      'StartTime': '2024-03-23T16:06:58.2676451-04:00',
#      'SubjectName': 'Trial 29_SI2_F_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_16-06-58_trial-29_si2_f_032324_trial-29_si2_f_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_16-06-58_trial-29_si2_f_032324_trial-29_si2_f_032324_results_00.yaml'],
#     'uuid': 'ad76460d-2e9b-41e4-bf90-9ae9e8b4a008'},
#    {'filename': '2024-03-23_16-37-57_trial-30_si16_f_032324_trial-30_si16_f_032324_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 30_SI16_F_032324',
#      'StartTime': '2024-03-23T16:37:57.1145831-04:00',
#      'SubjectName': 'Trial 30_SI16_F_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_16-37-57_trial-30_si16_f_032324_trial-30_si16_f_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_16-37-57_trial-30_si16_f_032324_trial-30_si16_f_032324_results_00.yaml'],
#     'uuid': '95139b60-45f6-4def-83de-aed1b8b76d5a'},
#    {'filename': '2024-03-23_17-05-59_trial-31_si4_f_032324_trial-31_si4_f_032324_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 31_SI4_F_032324',
#      'StartTime': '2024-03-23T17:05:59.9298743-04:00',
#      'SubjectName': 'Trial 31_SI4_F_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_17-05-59_trial-31_si4_f_032324_trial-31_si4_f_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_17-05-59_trial-31_si4_f_032324_trial-31_si4_f_032324_results_00.yaml'],
#     'uuid': 'c105c07c-cd24-4458-954b-3b94192581fa'},
#    {'filename': '2024-03-23_17-34-40_trial-32_si6_f_032324_trial-32_si6_f_032324_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 32_SI6_F_032324',
#      'StartTime': '2024-03-23T17:34:40.8827272-04:00',
#      'SubjectName': 'Trial 32_SI6_F_032324'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_17-34-40_trial-32_si6_f_032324_trial-32_si6_f_032324_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-23_17-34-40_trial-32_si6_f_032324_trial-32_si6_f_032324_results_00.yaml'],
#     'uuid': '324e0914-b42a-44c3-bf7b-63b9137ec702'},
#    {'filename': '2024-03-24_12-36-44_trial-33_si8_f_032424_trial-33_si8_f_032424_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 33_SI8_F_032424',
#      'StartTime': '2024-03-24T12:36:44.3185271-04:00',
#      'SubjectName': 'Trial 33_SI8_F_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_12-36-44_trial-33_si8_f_032424_trial-33_si8_f_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_12-36-44_trial-33_si8_f_032424_trial-33_si8_f_032424_results_00.yaml'],
#     'uuid': '64afa6b6-14d6-4579-b2fa-2fc80a6773a4'},
#    {'filename': '2024-03-24_13-04-58_trial-34_si10_f_032424_trial-34_si10_f_032424_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 34_SI10_F_032424',
#      'StartTime': '2024-03-24T13:04:58.7307905-04:00',
#      'SubjectName': 'Trial 34_SI10_F_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_13-04-58_trial-34_si10_f_032424_trial-34_si10_f_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_13-04-58_trial-34_si10_f_032424_trial-34_si10_f_032424_results_00.yaml'],
#     'uuid': '28f1ac0f-b2d2-4e2f-a87e-08f744694a12'},
#    {'filename': '2024-03-24_13-32-52_trial-35_si12_f_032424_trial-35_si12_f_032424_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 35_SI12_F_032424',
#      'StartTime': '2024-03-24T13:32:52.9936423-04:00',
#      'SubjectName': 'Trial 35_SI12_F_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_13-32-52_trial-35_si12_f_032424_trial-35_si12_f_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_13-32-52_trial-35_si12_f_032424_trial-35_si12_f_032424_results_00.yaml'],
#     'uuid': '2477af62-09b2-4ad9-a6ab-b02551cbfffe'},
#    {'filename': '2024-03-24_14-01-30_trial-36_si14_f_032424_trial-36_si14_f_032424_results_00.h5',
#     'group': 'SI',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 36_SI14_F_032424',
#      'StartTime': '2024-03-24T14:01:30.1963143-04:00',
#      'SubjectName': 'Trial 36_SI14_F_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_14-01-30_trial-36_si14_f_032424_trial-36_si14_f_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_14-01-30_trial-36_si14_f_032424_trial-36_si14_f_032424_results_00.yaml'],
#     'uuid': '17252c55-0e0e-413b-908d-c88ec5d212a9'},
#    {'filename': '2024-03-24_14-38-02_trial-37_ee4_f1_032424_trial-37_ee4_f1_032424_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 37_EE4_F1_032424',
#      'StartTime': '2024-03-24T14:38:02.2782679-04:00',
#      'SubjectName': 'Trial 37_EE4_F1_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_14-38-02_trial-37_ee4_f1_032424_trial-37_ee4_f1_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_14-38-02_trial-37_ee4_f1_032424_trial-37_ee4_f1_032424_results_00.yaml'],
#     'uuid': '7c62f537-ba9d-4f70-8010-d2a4d61fb68b'},
#    {'filename': '2024-03-24_15-07-54_trial-38_ee4_f2_032424_trial-38_ee4_f2_032424_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 38_EE4_F2_032424',
#      'StartTime': '2024-03-24T15:07:54.9419728-04:00',
#      'SubjectName': 'Trial 38_EE4_F2_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_15-07-54_trial-38_ee4_f2_032424_trial-38_ee4_f2_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_15-07-54_trial-38_ee4_f2_032424_trial-38_ee4_f2_032424_results_00.yaml'],
#     'uuid': '9bd917de-0f2c-4c91-997e-a0cfd5f3bee6'},
#    {'filename': '2024-03-24_15-37-50_trial-39_ee4_f3_032424_trial-39_ee4_f3_032424_results_00.h5',
#     'group': 'EE',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 39_EE4_F3_032424',
#      'StartTime': '2024-03-24T15:37:50.5710652-04:00',
#      'SubjectName': 'Trial 39_EE4_F3_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_15-37-50_trial-39_ee4_f3_032424_trial-39_ee4_f3_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_15-37-50_trial-39_ee4_f3_032424_trial-39_ee4_f3_032424_results_00.yaml'],
#     'uuid': '85c22ee9-57ac-43d0-aced-b2fe207e3f8b'},
#    {'filename': '2024-03-24_16-08-01_trial-40_ngh2_f1_032424_trial-40_ngh2_f1_032424_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 40_NGH2_F1_032424',
#      'StartTime': '2024-03-24T16:08:01.5725903-04:00',
#      'SubjectName': 'Trial 40_NGH2_F1_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_16-08-01_trial-40_ngh2_f1_032424_trial-40_ngh2_f1_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_16-08-01_trial-40_ngh2_f1_032424_trial-40_ngh2_f1_032424_results_00.yaml'],
#     'uuid': '97a57d78-d58e-4612-89b6-139b6abcc220'},
#    {'filename': '2024-03-24_16-37-15_trial-41_ngh2_f2_032424_trial-41_ngh2_f2_032424_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 41_NGH2_F2_032424',
#      'StartTime': '2024-03-24T16:37:15.9640663-04:00',
#      'SubjectName': 'Trial 41_NGH2_F2_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_16-37-15_trial-41_ngh2_f2_032424_trial-41_ngh2_f2_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_16-37-15_trial-41_ngh2_f2_032424_trial-41_ngh2_f2_032424_results_00.yaml'],
#     'uuid': 'ecbc70a6-5a82-4515-b634-3bc73aa5f630'},
#    {'filename': '2024-03-24_17-05-25_trial-42_ngh2_f3_032424_trial-42_ngh2_f3_032424_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 42_NGH2_F3_032424',
#      'StartTime': '2024-03-24T17:05:25.6934253-04:00',
#      'SubjectName': 'Trial 42_NGH2_F3_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_17-05-25_trial-42_ngh2_f3_032424_trial-42_ngh2_f3_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_17-05-25_trial-42_ngh2_f3_032424_trial-42_ngh2_f3_032424_results_00.yaml'],
#     'uuid': '50f85c58-5331-4aaa-a103-110eddf99f6e'},
#    {'filename': '2024-03-24_17-35-16_trial-43_ngh2_f4_032424_trial-43_ngh2_f4_032424_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'Trial 43_NGH2_F4_032424',
#      'StartTime': '2024-03-24T17:35:16.736479-04:00',
#      'SubjectName': 'Trial 43_NGH2_F4_032424'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_17-35-16_trial-43_ngh2_f4_032424_trial-43_ngh2_f4_032424_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_17-35-16_trial-43_ngh2_f4_032424_trial-43_ngh2_f4_032424_results_00.yaml'],
#     'uuid': '49fb2344-6151-4212-ade7-0f35dcd575c8'},
#    {'filename': '2024-04-22_10-01-58_mom_a_wt_lnb_3_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'MomA',
#      'StartTime': '2024-04-22T10:01:58.47119-04:00',
#      'SubjectName': 'WT_LNB_3'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_10-01-58_mom_a_wt_lnb_3_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_10-01-58_mom_a_wt_lnb_3_results_00.yaml'],
#     'uuid': '7da9f450-fa6a-4969-83fb-324c3ac64730'},
#    {'filename': '2024-04-22_10-56-04_mom_b_wt_ngh_4_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'MomB',
#      'StartTime': '2024-04-22T10:56:04.4713555-04:00',
#      'SubjectName': 'WT_NGH_4'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_10-56-04_mom_b_wt_ngh_4_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_10-56-04_mom_b_wt_ngh_4_results_00.yaml'],
#     'uuid': 'cf69575b-cbc2-4db4-9122-3c204af621bb'},
#    {'filename': '2024-04-22_11-49-33_mom_c_wt_lnb_4_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'MomC',
#      'StartTime': '2024-04-22T11:49:33.8244505-04:00',
#      'SubjectName': 'WT_LNB_4'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_11-49-33_mom_c_wt_lnb_4_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_11-49-33_mom_c_wt_lnb_4_results_00.yaml'],
#     'uuid': 'dbd0d73c-8b4d-4414-be60-d957a9babb60'},
#    {'filename': '2024-04-22_12-42-36_mom_d_wt_ngh_5_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'MomD',
#      'StartTime': '2024-04-22T12:42:36.7625829-04:00',
#      'SubjectName': 'WT_NGH_5'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_12-42-36_mom_d_wt_ngh_5_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_12-42-36_mom_d_wt_ngh_5_results_00.yaml'],
#     'uuid': '5d4776c5-58c7-4a22-a435-073944bd3edd'},
#    {'filename': '2024-04-22_13-35-41_mom_e_wt_lnb_5_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'MomE',
#      'StartTime': '2024-04-22T13:35:41.0835967-04:00',
#      'SubjectName': 'WT_LNB_5'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_13-35-41_mom_e_wt_lnb_5_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_13-35-41_mom_e_wt_lnb_5_results_00.yaml'],
#     'uuid': '44b5c9ec-dad3-496b-8c49-580f3ce4c551'},
#    {'filename': '2024-04-22_14-29-37_mom_f_wt_ngh_3_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'MomF',
#      'StartTime': '2024-04-22T14:29:37.0667612-04:00',
#      'SubjectName': 'WT_NGH_3'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_14-29-37_mom_f_wt_ngh_3_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_14-29-37_mom_f_wt_ngh_3_results_00.yaml'],
#     'uuid': 'b63d766a-ac38-4c3f-a119-f7ad4966bbc9'},
#    {'filename': '2024-05-01_11-12-18_ngh1_m1_050124_ngh1_m1_050124_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH1_M1_050124',
#      'StartTime': '2024-05-01T11:12:18.4942992-04:00',
#      'SubjectName': 'NGH1_M1_050124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_11-12-18_ngh1_m1_050124_ngh1_m1_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_11-12-18_ngh1_m1_050124_ngh1_m1_050124_results_00.yaml'],
#     'uuid': '39edc985-48d4-42ec-9e48-b5e899c843f4'},
#    {'filename': '2024-05-01_11-39-38_ngh1_m2_050124_ngh1_m2_050124_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH1_M2_050124',
#      'StartTime': '2024-05-01T11:39:38.8716626-04:00',
#      'SubjectName': 'NGH1_M2_050124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_11-39-38_ngh1_m2_050124_ngh1_m2_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_11-39-38_ngh1_m2_050124_ngh1_m2_050124_results_00.yaml'],
#     'uuid': '2d064006-b0f9-4695-9b42-917d5a7160cc'},
#    {'filename': '2024-05-01_12-08-18_ngh1_m3_050124_ngh1_m3_050124_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH1_M3_050124',
#      'StartTime': '2024-05-01T12:08:18.5545089-04:00',
#      'SubjectName': 'NGH1_M3_050124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_12-08-18_ngh1_m3_050124_ngh1_m3_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_12-08-18_ngh1_m3_050124_ngh1_m3_050124_results_00.yaml'],
#     'uuid': '37df5acb-dff2-4e01-ac11-75bb3f84723a'},
#    {'filename': '2024-05-01_12-39-43_ngh1_m4_050124_ngh1_m4_050124_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH1_M4_050124',
#      'StartTime': '2024-05-01T12:39:43.9566523-04:00',
#      'SubjectName': 'NGH1_M4_050124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_12-39-43_ngh1_m4_050124_ngh1_m4_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_12-39-43_ngh1_m4_050124_ngh1_m4_050124_results_00.yaml'],
#     'uuid': '09b57288-e6f3-42ec-bfed-892f9e89cc38'},
#    {'filename': '2024-05-01_13-19-22_lnb1_m1_050124_lnb1_m1_050124_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB1_M1_050124',
#      'StartTime': '2024-05-01T13:19:22.6517515-04:00',
#      'SubjectName': 'LNB1_M1_050124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_13-19-22_lnb1_m1_050124_lnb1_m1_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_13-19-22_lnb1_m1_050124_lnb1_m1_050124_results_00.yaml'],
#     'uuid': '720952da-bea0-41d2-b76f-70d00ed93f68'},
#    {'filename': '2024-05-01_13-48-24_lnb1_m2_050124_lnb1_m2_050124_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB1_M2_050124',
#      'StartTime': '2024-05-01T13:48:24.4781916-04:00',
#      'SubjectName': 'LNB1_M2_050124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_13-48-24_lnb1_m2_050124_lnb1_m2_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_13-48-24_lnb1_m2_050124_lnb1_m2_050124_results_00.yaml'],
#     'uuid': '3141d48d-1b0e-44f7-b409-3f4be3845375'},
#    {'filename': '2024-05-01_14-16-36_lnb1_m3_050124_lnb1_m3_050124_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB1_M3_050124',
#      'StartTime': '2024-05-01T14:16:36.462266-04:00',
#      'SubjectName': 'LNB1_M3_050124'},
#     'path': ['/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_14-16-36_lnb1_m3_050124_lnb1_m3_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_14-16-36_lnb1_m3_050124_lnb1_m3_050124_results_00.yaml'],
#     'uuid': '1cd315f5-04ff-4b57-b80e-c09fac0b6db0'},
# ...
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB1_M1_050124',
#      'StartTime': '2024-05-01T13:19:22.6517515-04:00',
#      'SubjectName': 'LNB1_M1_050124'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_13-19-22_lnb1_m1_050124_lnb1_m1_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_13-19-22_lnb1_m1_050124_lnb1_m1_050124_results_00.yaml')},
#    '3141d48d-1b0e-44f7-b409-3f4be3845375': {'filename': '2024-05-01_13-48-24_lnb1_m2_050124_lnb1_m2_050124_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB1_M2_050124',
#      'StartTime': '2024-05-01T13:48:24.4781916-04:00',
#      'SubjectName': 'LNB1_M2_050124'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_13-48-24_lnb1_m2_050124_lnb1_m2_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_13-48-24_lnb1_m2_050124_lnb1_m2_050124_results_00.yaml')},
#    '1cd315f5-04ff-4b57-b80e-c09fac0b6db0': {'filename': '2024-05-01_14-16-36_lnb1_m3_050124_lnb1_m3_050124_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB1_M3_050124',
#      'StartTime': '2024-05-01T14:16:36.462266-04:00',
#      'SubjectName': 'LNB1_M3_050124'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_14-16-36_lnb1_m3_050124_lnb1_m3_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_14-16-36_lnb1_m3_050124_lnb1_m3_050124_results_00.yaml')},
#    '08e8ec9a-89c4-4141-a9ac-6d969cc8a704': {'filename': '2024-05-01_14-43-42_lnb1_m4_050124_lnb1_m4_050124_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB1_M4_050124',
#      'StartTime': '2024-05-01T14:43:42.3514341-04:00',
#      'SubjectName': 'LNB1_M4_050124'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_14-43-42_lnb1_m4_050124_lnb1_m4_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_14-43-42_lnb1_m4_050124_lnb1_m4_050124_results_00.yaml')},
#    'fe483994-4b63-43bd-94db-ad8878ce5c68': {'filename': '2024-05-01_15-13-46_lnb2_m1_050124_lnb2_m1_050124_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB2_M1_050124',
#      'StartTime': '2024-05-01T15:13:46.9825068-04:00',
#      'SubjectName': 'LNB2_M1_050124'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_15-13-46_lnb2_m1_050124_lnb2_m1_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_15-13-46_lnb2_m1_050124_lnb2_m1_050124_results_00.yaml')},
#    '76c4755b-6e92-41e6-bbba-4a44fee3c2b3': {'filename': '2024-05-01_15-41-26_lnb2_m2_050124_lnb2_m2_050124_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB2_M2_050124',
#      'StartTime': '2024-05-01T15:41:26.9803391-04:00',
#      'SubjectName': 'LNB2_M2_050124'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_15-41-26_lnb2_m2_050124_lnb2_m2_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_15-41-26_lnb2_m2_050124_lnb2_m2_050124_results_00.yaml')},
#    'f13b0e8c-e103-42db-a09a-b7e504cc8e98': {'filename': '2024-05-01_16-09-03_lnb2_m3_050124_lnb2_m3_050124_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB2_M3_050124',
#      'StartTime': '2024-05-01T16:09:03.0854233-04:00',
#      'SubjectName': 'LNB2_M3_050124'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_16-09-03_lnb2_m3_050124_lnb2_m3_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_16-09-03_lnb2_m3_050124_lnb2_m3_050124_results_00.yaml')},
#    'd43c418d-31b9-444f-ad3c-f866650d8d48': {'filename': '2024-05-01_16-39-14_ngh2_m1_050124_ngh2_m1_050124_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH2_M1_050124',
#      'StartTime': '2024-05-01T16:39:14.5721715-04:00',
#      'SubjectName': 'NGH2_M1_050124'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_16-39-14_ngh2_m1_050124_ngh2_m1_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_16-39-14_ngh2_m1_050124_ngh2_m1_050124_results_00.yaml')},
#    'f6acaf70-9a0c-4153-8b8d-6ab7f30f5086': {'filename': '2024-05-01_17-07-17_ngh2_m2_050124_ngh2_m2_050124_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH2_M2_050124',
#      'StartTime': '2024-05-01T17:07:17.6283237-04:00',
#      'SubjectName': 'NGH2_M2_050124'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_17-07-17_ngh2_m2_050124_ngh2_m2_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_17-07-17_ngh2_m2_050124_ngh2_m2_050124_results_00.yaml')},
#    '54e64461-fe5b-4218-b289-6967f90f5a3f': {'filename': '2024-05-01_17-35-13_ngh2_m3_050124_ngh2_m3_050124_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH2_M3_050124',
#      'StartTime': '2024-05-01T17:35:13.1248465-04:00',
#      'SubjectName': 'NGH2_M3_050124'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_17-35-13_ngh2_m3_050124_ngh2_m3_050124_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-01_17-35-13_ngh2_m3_050124_ngh2_m3_050124_results_00.yaml')},
#    'ac7313e1-2773-4697-92ae-65cc26fa5bb0': {'filename': '2024-05-02_12-25-55_ngh3_f1_050224_ngh3_f1_050224_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH3_F1_050224',
#      'StartTime': '2024-05-02T12:25:55.4828902-04:00',
#      'SubjectName': 'NGH3_F1_050224'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_12-25-55_ngh3_f1_050224_ngh3_f1_050224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_12-25-55_ngh3_f1_050224_ngh3_f1_050224_results_00.yaml')},
#    '766729c8-fb8f-45af-b570-9f01ee57bad5': {'filename': '2024-05-02_12-53-41_ngh3_f2_050224_ngh3_f2_050224_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH3_F2_050224',
#      'StartTime': '2024-05-02T12:53:41.3486205-04:00',
#      'SubjectName': 'NGH3_F2_050224'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_12-53-41_ngh3_f2_050224_ngh3_f2_050224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_12-53-41_ngh3_f2_050224_ngh3_f2_050224_results_00.yaml')},
#    '44fabafe-c6da-4f0c-811f-88d094b74579': {'filename': '2024-05-02_13-21-42_ngh3_f3_050224_ngh3_f3_050224_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH3_F3_050224',
#      'StartTime': '2024-05-02T13:21:42.7610356-04:00',
#      'SubjectName': 'NGH3_F3_050224'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_13-21-42_ngh3_f3_050224_ngh3_f3_050224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_13-21-42_ngh3_f3_050224_ngh3_f3_050224_results_00.yaml')},
#    '2ab5b5a7-d47a-4c10-b419-0d14fb56bdfb': {'filename': '2024-05-02_13-50-20_ngh3_f4_050224_ngh3_f4_050224_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH3_F4_050224',
#      'StartTime': '2024-05-02T13:50:20.6648129-04:00',
#      'SubjectName': 'NGH3_F4_050224'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_13-50-20_ngh3_f4_050224_ngh3_f4_050224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_13-50-20_ngh3_f4_050224_ngh3_f4_050224_results_00.yaml')},
#    '188d5be9-0528-44f9-ae35-99be67beac81': {'filename': '2024-05-02_14-27-38_lnb3_f1_050224_lnb3_f1_050224_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB3_F1_050224',
#      'StartTime': '2024-05-02T14:27:38.1534471-04:00',
#      'SubjectName': 'LNB3_F1_050224'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_14-27-38_lnb3_f1_050224_lnb3_f1_050224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_14-27-38_lnb3_f1_050224_lnb3_f1_050224_results_00.yaml')},
#    '6893dc2a-0ab2-44f9-bf00-d0f1fc7fd468': {'filename': '2024-05-02_14-56-19_lnb3_f2_050224_lnb3_f2_050224_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB3_F2_050224',
#      'StartTime': '2024-05-02T14:56:19.2617926-04:00',
#      'SubjectName': 'LNB3_F2_050224'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_14-56-19_lnb3_f2_050224_lnb3_f2_050224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_14-56-19_lnb3_f2_050224_lnb3_f2_050224_results_00.yaml')},
#    'd66226e7-616d-44dc-a325-391e0e0459bd': {'filename': '2024-05-02_15-24-26_lnb3_f3_050224_lnb3_f3_050224_results_00.h5',
#     'group': 'LNB',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'LNB3_F3_050224',
#      'StartTime': '2024-05-02T15:24:26.7132283-04:00',
#      'SubjectName': 'LNB3_F3_050224'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_15-24-26_lnb3_f3_050224_lnb3_f3_050224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_15-24-26_lnb3_f3_050224_lnb3_f3_050224_results_00.yaml')},
#    '79ef439a-2eff-4654-a777-559dcb343c96': {'filename': '2024-05-02_15-54-38_ngh4_f1_050224_ngh4_f1_050224_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH4_F1_050224',
#      'StartTime': '2024-05-02T15:54:38.681164-04:00',
#      'SubjectName': 'NGH4_F1_050224'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_15-54-38_ngh4_f1_050224_ngh4_f1_050224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_15-54-38_ngh4_f1_050224_ngh4_f1_050224_results_00.yaml')},
#    'e2100b8e-5270-4b2b-932a-25c349623cea': {'filename': '2024-05-02_16-24-34_ngh4_f2_050224_ngh4_f2_050224_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH4_F2_050224',
#      'StartTime': '2024-05-02T16:24:34.1051189-04:00',
#      'SubjectName': 'NGH4_F2_050224'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-24-34_ngh4_f2_050224_ngh4_f2_050224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-24-34_ngh4_f2_050224_ngh4_f2_050224_results_00.yaml')},
#    'd5c8746d-8f6a-439a-a9db-e20859b863c5': {'filename': '2024-05-02_16-54-44_ngh4_f3_050224_ngh4_f3_050224_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'ColorResolution': [512, 424],
#      'DepthDataType': 'UInt16[]',
#      'DepthResolution': [512, 424],
#      'IsLittleEndian': True,
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'NGH4_F3_050224',
#      'StartTime': '2024-05-02T16:54:44.1131268-04:00',
#      'SubjectName': 'NGH4_F3_050224'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-54-44_ngh4_f3_050224_ngh4_f3_050224_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-54-44_ngh4_f3_050224_ngh4_f3_050224_results_00.yaml')},
#    'cf3f996b-e103-464f-b132-cfeeeb9e61ed': {'filename': '_session_20240321150325_session_20240321150325_results_00.h5',
#     'group': 'NGH',
#     'metadata': {'ColorDataType': 'Byte[]',
#      'DepthResolution': [512, 424],
#      'NidaqChannels': 0,
#      'NidaqSamplingRate': 0.0,
#      'SessionName': 'session_20240321150325',
#      'StartTime': '',
#      'SubjectName': 'session_20240321150325'},
#     'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/_session_20240321150325_session_20240321150325_results_00.h5',
#      '/om2/user/rraju/data/moseq_data/aggregate_results/_session_20240321150325_session_20240321150325_results_00.yaml')}},
#   'pca_path': '/om2/user/rraju/data/moseq_data/'})

# %%
progress_paths['index_file']
# Out:
# '/om2/user/rraju/data/moseq_data/moseq2-index.yaml'

# %%
[print(item) for item in sorted_index['files']]
# Out:
# 36924daa-7b3f-4fbb-a1fc-46d2c28fb505
# 156dc2ef-544c-41e0-ae8a-45ca5f39fbdb
# 5e985ff0-2f88-4193-bb49-7bc4256e0228
# 4c5ecb1f-c9dc-48e5-89f1-03d88beceddd
# 45c06e3e-4c2e-4fa7-b8c8-11e9d9b20616
# 52219521-6c81-4cb1-83b8-1a91b652e2ed
# ded0375b-8f4a-40e6-a768-2b7fdcb340d0
# 9043b3df-a659-40a0-8a7f-00f40bf4211a
# 23aa4f10-384e-4dc0-a81a-2e9fa1567967
# d7430e64-b209-46e8-a3fe-1aa583ab8500
# 655004cd-f1c3-4141-b00a-5206b202aaf6
# 9a8900b5-34ab-48e7-9a17-d845b3590603
# 9d865df3-1e3b-4ba1-86d2-95c5abb87ddd
# 58645376-1524-4e4b-8468-48010fbb9449
# 07de674a-66b2-4780-9fb1-a71670d1942f
# 16faf940-bd28-4fbf-8d0d-ca7ff1179a5c
032424'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_14-38-02_trial-37_ee4_f1_032424_trial-37_ee4_f1_032424_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_14-38-02_trial-37_ee4_f1_032424_trial-37_ee4_f1_032424_results_00.yaml')},
#   '9bd917de-0f2c-4c91-997e-a0cfd5f3bee6': {'filename': '2024-03-24_15-07-54_trial-38_ee4_f2_032424_trial-38_ee4_f2_032424_results_00.h5',
#    'group': 'EE',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'Trial 38_EE4_F2_032424',
#     'StartTime': '2024-03-24T15:07:54.9419728-04:00',
#     'SubjectName': 'Trial 38_EE4_F2_032424'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_15-07-54_trial-38_ee4_f2_032424_trial-38_ee4_f2_032424_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_15-07-54_trial-38_ee4_f2_032424_trial-38_ee4_f2_032424_results_00.yaml')},
#   '85c22ee9-57ac-43d0-aced-b2fe207e3f8b': {'filename': '2024-03-24_15-37-50_trial-39_ee4_f3_032424_trial-39_ee4_f3_032424_results_00.h5',
#    'group': 'EE',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'Trial 39_EE4_F3_032424',
#     'StartTime': '2024-03-24T15:37:50.5710652-04:00',
#     'SubjectName': 'Trial 39_EE4_F3_032424'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_15-37-50_trial-39_ee4_f3_032424_trial-39_ee4_f3_032424_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_15-37-50_trial-39_ee4_f3_032424_trial-39_ee4_f3_032424_results_00.yaml')},
#   '97a57d78-d58e-4612-89b6-139b6abcc220': {'filename': '2024-03-24_16-08-01_trial-40_ngh2_f1_032424_trial-40_ngh2_f1_032424_results_00.h5',
#    'group': 'NGH',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'Trial 40_NGH2_F1_032424',
#     'StartTime': '2024-03-24T16:08:01.5725903-04:00',
#     'SubjectName': 'Trial 40_NGH2_F1_032424'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_16-08-01_trial-40_ngh2_f1_032424_trial-40_ngh2_f1_032424_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_16-08-01_trial-40_ngh2_f1_032424_trial-40_ngh2_f1_032424_results_00.yaml')},
#   'ecbc70a6-5a82-4515-b634-3bc73aa5f630': {'filename': '2024-03-24_16-37-15_trial-41_ngh2_f2_032424_trial-41_ngh2_f2_032424_results_00.h5',
#    'group': 'NGH',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'Trial 41_NGH2_F2_032424',
#     'StartTime': '2024-03-24T16:37:15.9640663-04:00',
#     'SubjectName': 'Trial 41_NGH2_F2_032424'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_16-37-15_trial-41_ngh2_f2_032424_trial-41_ngh2_f2_032424_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_16-37-15_trial-41_ngh2_f2_032424_trial-41_ngh2_f2_032424_results_00.yaml')},
#   '50f85c58-5331-4aaa-a103-110eddf99f6e': {'filename': '2024-03-24_17-05-25_trial-42_ngh2_f3_032424_trial-42_ngh2_f3_032424_results_00.h5',
#    'group': 'NGH',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'Trial 42_NGH2_F3_032424',
#     'StartTime': '2024-03-24T17:05:25.6934253-04:00',
#     'SubjectName': 'Trial 42_NGH2_F3_032424'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_17-05-25_trial-42_ngh2_f3_032424_trial-42_ngh2_f3_032424_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_17-05-25_trial-42_ngh2_f3_032424_trial-42_ngh2_f3_032424_results_00.yaml')},
#   '49fb2344-6151-4212-ade7-0f35dcd575c8': {'filename': '2024-03-24_17-35-16_trial-43_ngh2_f4_032424_trial-43_ngh2_f4_032424_results_00.h5',
#    'group': 'NGH',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'Trial 43_NGH2_F4_032424',
#     'StartTime': '2024-03-24T17:35:16.736479-04:00',
#     'SubjectName': 'Trial 43_NGH2_F4_032424'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_17-35-16_trial-43_ngh2_f4_032424_trial-43_ngh2_f4_032424_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-03-24_17-35-16_trial-43_ngh2_f4_032424_trial-43_ngh2_f4_032424_results_00.yaml')},
#   '7da9f450-fa6a-4969-83fb-324c3ac64730': {'filename': '2024-04-22_10-01-58_mom_a_wt_lnb_3_results_00.h5',
#    'group': 'LNB',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'MomA',
#     'StartTime': '2024-04-22T10:01:58.47119-04:00',
#     'SubjectName': 'WT_LNB_3'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_10-01-58_mom_a_wt_lnb_3_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_10-01-58_mom_a_wt_lnb_3_results_00.yaml')},
#   'cf69575b-cbc2-4db4-9122-3c204af621bb': {'filename': '2024-04-22_10-56-04_mom_b_wt_ngh_4_results_00.h5',
#    'group': 'NGH',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'MomB',
#     'StartTime': '2024-04-22T10:56:04.4713555-04:00',
#     'SubjectName': 'WT_NGH_4'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_10-56-04_mom_b_wt_ngh_4_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_10-56-04_mom_b_wt_ngh_4_results_00.yaml')},
#   'dbd0d73c-8b4d-4414-be60-d957a9babb60': {'filename': '2024-04-22_11-49-33_mom_c_wt_lnb_4_results_00.h5',
#    'group': 'LNB',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'MomC',
#     'StartTime': '2024-04-22T11:49:33.8244505-04:00',
#     'SubjectName': 'WT_LNB_4'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_11-49-33_mom_c_wt_lnb_4_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_11-49-33_mom_c_wt_lnb_4_results_00.yaml')},
#   '5d4776c5-58c7-4a22-a435-073944bd3edd': {'filename': '2024-04-22_12-42-36_mom_d_wt_ngh_5_results_00.h5',
#    'group': 'NGH',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'MomD',
#     'StartTime': '2024-04-22T12:42:36.7625829-04:00',
#     'SubjectName': 'WT_NGH_5'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_12-42-36_mom_d_wt_ngh_5_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_12-42-36_mom_d_wt_ngh_5_results_00.yaml')},
#   '44b5c9ec-dad3-496b-8c49-580f3ce4c551': {'filename': '2024-04-22_13-35-41_mom_e_wt_lnb_5_results_00.h5',
#    'group': 'LNB',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'MomE',
#     'StartTime': '2024-04-22T13:35:41.0835967-04:00',
#     'SubjectName': 'WT_LNB_5'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22_13-35-41_mom_e_wt_lnb_5_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-04-22
024-05-02_15-54-38_ngh4_f1_050224_ngh4_f1_050224_results_00.h5',
#    'group': 'NGH',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'NGH4_F1_050224',
#     'StartTime': '2024-05-02T15:54:38.681164-04:00',
#     'SubjectName': 'NGH4_F1_050224'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_15-54-38_ngh4_f1_050224_ngh4_f1_050224_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_15-54-38_ngh4_f1_050224_ngh4_f1_050224_results_00.yaml')},
#   'e2100b8e-5270-4b2b-932a-25c349623cea': {'filename': '2024-05-02_16-24-34_ngh4_f2_050224_ngh4_f2_050224_results_00.h5',
#    'group': 'NGH',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'NGH4_F2_050224',
#     'StartTime': '2024-05-02T16:24:34.1051189-04:00',
#     'SubjectName': 'NGH4_F2_050224'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-24-34_ngh4_f2_050224_ngh4_f2_050224_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-24-34_ngh4_f2_050224_ngh4_f2_050224_results_00.yaml')},
#   'd5c8746d-8f6a-439a-a9db-e20859b863c5': {'filename': '2024-05-02_16-54-44_ngh4_f3_050224_ngh4_f3_050224_results_00.h5',
#    'group': 'NGH',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'ColorResolution': [512, 424],
#     'DepthDataType': 'UInt16[]',
#     'DepthResolution': [512, 424],
#     'IsLittleEndian': True,
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'NGH4_F3_050224',
#     'StartTime': '2024-05-02T16:54:44.1131268-04:00',
#     'SubjectName': 'NGH4_F3_050224'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-54-44_ngh4_f3_050224_ngh4_f3_050224_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/2024-05-02_16-54-44_ngh4_f3_050224_ngh4_f3_050224_results_00.yaml')},
#   'cf3f996b-e103-464f-b132-cfeeeb9e61ed': {'filename': '_session_20240321150325_session_20240321150325_results_00.h5',
#    'group': 'NGH',
#    'metadata': {'ColorDataType': 'Byte[]',
#     'DepthResolution': [512, 424],
#     'NidaqChannels': 0,
#     'NidaqSamplingRate': 0.0,
#     'SessionName': 'session_20240321150325',
#     'StartTime': '',
#     'SubjectName': 'session_20240321150325'},
#    'path': ('/om2/user/rraju/data/moseq_data/aggregate_results/_session_20240321150325_session_20240321150325_results_00.h5',
#     '/om2/user/rraju/data/moseq_data/aggregate_results/_session_20240321150325_session_20240321150325_results_00.yaml')}},
#  'pca_path': '/om2/user/rraju/data/moseq_data/_pca/pca_scores.h5'}

# %% [markdown]
# ## Export `moseq_df`
#
# You can export the `moseq_df` to a csv file (or other alternative file types) for further analysis using the following cell. [See here](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html) for a list of alternative file formats to save `moseq_df`.
#
# **Note:** it can take quite a while to export the `moseq_df`, especially if it is saved as a `.csv` file. Check out [pandas's user guide](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html) to see if other formats will work better for you.
#
# **Instructions:**
# - **Specify the folder** you want to save the dataframe in `save_path`. By default, the file will be saved to `base_dir`.
# - **Run the following cell** to save `moseq_df` as a CSV file.

# %%
# Save `moseq_df` as a csv file
from os.path import exists, join

# Specify the place you want to save the dataframe in `save_path`
save_path = progress_paths['model_session_path']  # save the dataframe in the model specific folder

# exports the dataframe
filename = 'moseq_df.csv'
# here we use .to_csv to export the dataframe, but you can change it to try other ways of saving your data
moseq_df.to_csv(join(save_path, filename), index=False)

print('DataFrame is saved:', join(save_path, filename))
# Out:
# DataFrame is saved: /om2/user/rraju/data/moseq_data/models/model-007-12915497/moseq_df.csv

# %% [markdown]
# ## Compute `stats_df`
# `stats_df` is a `DataFrame` that contains statistical summaries (i.e., min, max, mean, std) of scalar values associated with each syllable, as well as the frequency each syllable is expressed. By default, it is computed using the features included in `moseq_df` for each session independently. This dataframe will be used to plot syllable statistics and perform hypothesis testing.
#
# The function can group data into whichever categories you supply into the `groupby` parameter.
# By default, we group by "group" (the experimental cohort) and "uuid" (each unique recording session).
# An alternative is to groupby by experimental cohort and mouse: `groupby = ['group', 'SubjectName']`.
# Under the hood, we use `pandas` to perform the `groupby` calculation.
# To learn more about `pandas`'s `groupby` capabilities, check out [their documentation](https://pandas.pydata.org/docs/user_guide/groupby.html#groupby) on the subject.
#
# By default, each row of the `stats_df` contains the average syllable usage for one syllable for one group (experimental cohort) within one uuid (session). Changing the contents of the `groupby` variable will change the contents of the `stats_df`.
#
# **Instructions:**
# - **Run the following cell**.

# %%
# compute syllable usage and scalar statistics
from moseq2_viz.model.util import compute_behavioral_statistics

count = 'usage'  # can either be usage or frames
syllable_key = 'labels (usage sort)'  # either 'labels (usage sort)', 'labels', or 'labels (frames sort)'
groupby = ['group', 'uuid']  # can be any categorical variables
usage_normalization = True  # turn syllable usage into a probability distribution from raw counts

stats_df = compute_behavioral_statistics(moseq_df, count=count, groupby=groupby, usage_normalization=usage_normalization, syllable_key=syllable_key)
print('The shape of stats_df', stats_df.shape)
stats_df.head()
# Out:
# The shape of stats_df (4712, 90)
#         group                                  uuid  syllable     usage  \
# 0  EE_Regular  01ef56de-c85a-4aef-9085-78aeb030c1eb         0  0.048097
# 1  EE_Regular  0eef51e1-6772-4133-9d0b-06e5fa2646d1         0  0.033217
# 2  EE_Regular  14d37c60-545c-4d5a-8ed5-605fce771241         0  0.079122
# 3  EE_Regular  1680002c-943a-4ca5-941b-47c7dda6110d         0  0.054618
# 4  EE_Regular  20bb2e09-b80a-4967-8a81-d6c0b68ea2dd         0  0.048747
#
#    duration  frame index_mean  frame index_std  frame index_min  \
# 0  0.586081      15386.972656     10873.906250             79.0
# 1  0.497661      24801.761719      8518.404297           5731.0
# 2  0.618280      14879.094727     12014.244141            472.0
# 3  0.456640      15685.595703     10127.935547             39.0
# 4  0.540952      19697.093750     10752.522461            191.0
#
#    frame index_max  kappa_mean  ...  width_px_max  dist_to_center_px_mean  \
# 0          35551.0  12915497.0  ...     22.051533               70.647583
# 1          35618.0  12915497.0  ...     19.554937               73.481918
# 2          35920.0  12915497.0  ...     23.307608               78.754929
# 3          35798.0  12915497.0  ...     19.261959               81.822151
# 4          35895.0  12915497.0  ...     18.422350               79.046776
#
#    dist_to_center_px_std  dist_to_center_px_min  dist_to_center_px_max  \
# 0              23.698011               9.066064             110.665497
# 1              22.461281              14.806916             109.346970
# 2              21.108326               2.555921             105.199669
# 3              19.738379               1.896879             106.128899
# 4              20.893127               6.003972             108.566811
#
#    timestamps_mean  timestamps_std  timestamps_min  timestamps_max  \
# 0     1.108217e+07   362628.573250    1.057181e+07    1.175531e+07
# 1     1.330424e+07   284096.750651    1.266840e+07    1.366533e+07
# 2     1.080222e+07   400474.624060    1.032198e+07    1.150358e+07
# 3     1.106004e+07   337751.483809    1.053837e+07    1.173127e+07
# 4     9.453089e+06   358481.113292    8.802842e+06    9.993474e+06
#
#           syllable key
# 0  labels (usage sort)
# 1  labels (usage sort)
# 2  labels (usage sort)
# 3  labels (usage sort)
# 4  labels (usage sort)
#
# [5 rows x 90 columns]

# %% [markdown]
# ## Export `stats_df`
#
# You can export the `stats_df` to a csv file for further analysis using the following cell.
#
# **Instructions:**
# - **Specify the place** you want to save the dataframe in `save_path`. By default, the file will be saved to `base_dir`.
# - **Run the following cell** to save `stats_df` as a CSV file.

# %%
# Save `stats_df` as a csv file
from os.path import exists, join

# Specify the place you want to save the dataframe in `save_path`
save_path = progress_paths['model_session_path']  # save the dataframe in the model specific folder

# exports the dataframe
filename = 'stats_df.csv'
stats_df.to_csv(join(save_path, filename), index=False)

print('DataFrame is saved:', join(save_path, filename))
# Out:
# DataFrame is saved: /om2/user/rraju/data/moseq_data/models/model-007-12915497/stats_df.csv

# %% [markdown]
# ## Generate Behavioral Summary (Fingerprints)
# Fingerprints summarize behavior by showing distributions of scalars (eg. position, velocity, height, and length) and syllables.
# These plots can be used as a useful diagnostic tool.
# Sessions where the mouse wasn't extracted properly or moves too much or little can be identified in these plots.
# You can find more information in the wiki [here](https://github.com/dattalab/moseq2-app/wiki/MoSeq2-Analysis-Visualization-Notebook-Instructions#fingerprint-plots).
#
# The following cell generates the summary dataframe and plots the behavioral summary. The fingerprint plot will be automatically saved as png and pdf in the `plots` folder in the model directory.
#
# **Instructions:**
# - **Set `n_bins` variable** to an integer to specify the number of bins for the MoSeq scalar values. Set `n_bins` variable to `None` if you want the number of bins to match the number of syllables. `n_bins` does not bin syllables.
# - **Set `range_type` variable** to 'robust' to include data ranging from 1 percentile top 99 percentile. **Set `range_type` variable** to 'full' to include all the data.
# - **Assign an `sklearn.preprocessing` object to `preprocessor` variable** if you want to scale the values by session. `preprocessor` variable is set to `None`, the figure will show the proportion of data filling each bin.
# - **Run the following cell.**

# %%
from moseq2_viz.model.fingerprint_classifier import create_fingerprint_dataframe, plotting_fingerprint
from sklearn.preprocessing import MinMaxScaler, StandardScaler

stat_type = 'mean'
n_bins = 100  # resolution of distribution 
range_type = 'full'  # robust or full
preprocessor = MinMaxScaler()

summary, range_dict = create_fingerprint_dataframe(moseq_df, stats_df, stat_type=stat_type, n_bins=n_bins, range_type=range_type)
plotting_fingerprint(summary, progress_paths['plot_path'], range_dict, preprocessor=preprocessor)

# %%
from moseq2_viz.model.fingerprint_classifier import create_fingerprint_dataframe, plotting_fingerprint
from sklearn.preprocessing import MinMaxScaler, StandardScaler

stat_type = 'mean'
n_bins = 100  # resolution of distribution 
range_type = 'robust'  # robust or full
preprocessor = MinMaxScaler()

summary, range_dict = create_fingerprint_dataframe(moseq_df, stats_df, stat_type=stat_type, n_bins=n_bins, range_type=range_type)
plotting_fingerprint(summary, progress_paths['plot_path'], range_dict, preprocessor=preprocessor)

# %% [markdown]
# #  Crowd Movie Generation and Interactive Syllable Labelling Tool
# Syllable crowd movies are movies that superimpose examples of mice in each syllable labeled by MoSeq.
# Crowd movies are a tool for learning which behaviors are captured by each syllable and you can assign behavioral labels and short descriptions to syllables by observing the crowd movies for further analysis.
# When a red dot appears over the mouse's body, it means that they are performing the specific syllable in the crowd movie.
# You can find more information in the [wiki](https://github.com/dattalab/moseq2-app/wiki/MoSeq2-Analysis-Visualization-Notebook-Instructions#interactive-syllable-labelling).
#
# After running the syllable labeler tool, syllable crowd movies based on the model of interest will be generated in its model-specific folder, as well as a [syll_info.yaml file](https://github.com/dattalab/moseq2-app/wiki/Directory-Structures-and-yaml-Files-in-MoSeq-Pipeline#syll_infoyaml).
# The `syll_info.yaml` file will contain entries for all syllables that explain `explained_variance`% of frames.
# For example, if 6 syllables explained 50% of all frames, then `syll_info.yaml` will contain entries for those 6 syllables.
# At this stage, syllables are relabeled by usage.
# You can find more information about the file structure after running the interactive syllable labeler tool [here](https://github.com/dattalab/moseq2-app/wiki/Directory-Structures-and-yaml-Files-in-MoSeq-Pipeline/#after-running-syllable-labeller).
#
# Run the following cell to start the interactive widget and assign labels and short descriptions (both optional) to syllables by observing the crowd movies and syllable statistics.
# The explained variance plot will be automatically saved to the `plots` folder in the model directory.
#
# **Note:** sometimes this widget can take a while to load or switch between syllables. Please be patient.
#
# **Instructions:**
# - **Run the following cell.**
# - **Select a syllable** from the `Syllable` dropdown menu to view the associated crowd movie and syllable info.
# - **Adjust the crowd movie playback speed using the `Playback Speed` slider** to better observe the behavior associated with short/fast syllables.
# - **Input the syllable behavioral label and short description** in the text fields.
# - Click `Save Setting` to save the syllable label and description for later analysis.
# - Use `Next` and `Previous` to navigate between syllables and the syllable label and description will be automatically saved when using these buttons.

# %%
from os.path import join
from moseq2_app.main import label_syllables
from moseq2_app.gui.progress import update_progress

#sorted_index['pca_path'] = '/om2/user/rraju/data/moseq_data/_pca/pca_scores.h5'

# Path to generate crowd movies in
crowd_dir = join(progress_paths['model_session_path'], 'crowd_movies/')

# Path to file containing Syllable label information
syll_infopath = join(progress_paths['model_session_path'], 'syll_info.yaml')

# convenience file containing reused syllable statistics data
syll_info_df_path = join(progress_paths['model_session_path'], 'syll_df.parquet')

# Select number of syllables based on an explained variance percentage
explained_variance = 99

# To instead label a fixed number of syllables, set max_syllables <= nstates
max_syllables = None

# To specify number of mouse examples in the syallable crowd movies
max_examples = 20

# To generate crowd movies selecting syllable instances that are close to syllable duration median
# set select_median_duration_instances = True and delete the existing crowd_movie folder
select_median_duration_instances = False

update_progress(progress_filepath, 'crowd_dir', crowd_dir)
update_progress(progress_filepath, 'syll_info', syll_infopath)
progress_paths = update_progress(progress_filepath, 'df_info_path', syll_info_df_path)

# max syllables is re-defined here
max_syllables = label_syllables(progress_paths, max_syllables=max_syllables, n_explained=explained_variance, select_median_duration_instances=select_median_duration_instances, max_examples=max_examples)
# Out:
# Variables are the same. No update necessary.
# Variables are the same. No update necessary.
# Variables are the same. No update necessary.
# Number of syllables explaining 99% variance: 53
# HBox(children=(FloatProgress(value=0.0, description='Creating MoSeq DataFrame', max=76.0, style=ProgressStyle(…
# Button(description='Clear Output', style=ButtonStyle(), tooltip='Close Cell Output')
# Dropdown(description='Syllable #:', options={'0 - ': {'label': '', 'desc': '', 'crowd_movie_path': '/om2/user/…
# Output()

# %% [markdown]
# #  Generate Syllable Dendrogram
# The similarity dendrogram represents the hierarchically sorted pairwise distances between the given model's autoregressive matrices representing the syllables. The cell uses information from `syll_info.yaml` [file](https://github.com/dattalab/moseq2-app/wiki/Directory-Structures-and-yaml-Files-in-MoSeq-Pipeline#syll_infoyaml) generated in the previous cell. The dendrogram is automatically saved to saved as png and pdf in the `plots` folder in the model directory.
#
# **Instructions:**
# - **Run the following cell.**

# %%
from moseq2_app.main import show_dendrogram

# max_syllables is defined above. Uncomment and change the line below if you want to manually set syllable number.
# max_syllables = 100
# Set color_by_cluster to True to color the syllables by similarity clusters
show_dendrogram(progress_paths, max_syllable=max_syllables, color_by_cluster=False)

# %% [markdown]
# # Interactive Syllable Statistics Graphing
# Syllable statistics provide information about the behavioral patterns and you can find more information in the [wiki](https://github.com/dattalab/moseq2-app/wiki/MoSeq2-Analysis-Visualization-Notebook-Instructions#interactive-syllable-statistics-graphing).
#
# Run the following cell to start the interactive widget to plot different syllable statistics and their differences in the modeled groups.
# This cell is dependent upon the previous cell to generate crowd movies and the `syll_info.yaml` [file](https://github.com/dattalab/moseq2-app/wiki/Directory-Structures-and-yaml-Files-in-MoSeq-Pipeline#syll_infoyaml).
#
# **NOTE**: this widget can take a while to render after changing parameters within the widget, so hang tight.
#
# **Instructions:**
# - **Run the following cell.**
# - **Select the parameter(s) from the dropdown menus** parameters to control the graph.
# - To plot multiple sessions and subjects, **select multiple sessions from `SessionName` or `SubjectName` while holding down the [Ctrl]/[Command]/[Shift] key**.
# - **Hover over the data points** to display syllable info.
# - **Click the save icon in the toolbar on the side of the figures** to save the figures as SVG in your default web image download folder.

# %%
from moseq2_app.main import interactive_syllable_stats

# If you want to overwrite dataframe files, set load_parquet=False
# max_syllables is defined above. Uncomment and change the line below if you want to manually set syllable number.
# max_syllables = 100
interactive_syllable_stats(progress_paths, max_syllable=max_syllables, load_parquet=True)
# Out:
# Syllable DataFrame not found. Computing syllable statistics...
# HBox(children=(FloatProgress(value=0.0, description='Creating MoSeq DataFrame', max=76.0, style=ProgressStyle(…
# Button(description='Clear Output', style=ButtonStyle(), tooltip='Close Cell Output')
# VBox(children=(HBox(children=(VBox(children=(VBox(children=(Dropdown(description='Stat to Plot:', options=('us…
# Output()

# %% [markdown]
# # Compute Syllable Transition Matrices
# Transition matrices compactly represent the frequency any syllable transitions into any other syllable and is one way to describe structure in behavior.
# The row of the transition matrix represents an incoming syllable, while the column represents the outgoing syllable and the value at a specific row and column position represent the frequency the incoming syllable transitions into the outgoing syllable.
#
# These plots can help visualize gross changes in the structure of behavior between two experimental groups. For example, certain syllables that frequently transition into one set of syllables in one experimental condition might transition into a completely different set in another experimental condition.
#
# The following cell computes syllable transition matrices for each group. The figures will be automatically saved as png and pdf in the `plots` folder in the model directory.
#
# **Note**: This code block is loading the model from the `model_path` set in the `progress_paths` config.
#
# **Instructions:**
# - **Run the following cell to plot the transition matrices.**

# %%
import os
import matplotlib.pyplot as plt
from moseq2_viz.model.util import parse_model_results, relabel_by_usage
from moseq2_viz.model.trans_graph import get_trans_graph_groups, get_group_trans_mats

# syllable threshold defined above. Uncomment if you want to manually set
# max_syllables = 40

# select a transition matrix normalization method
normalize = 'bigram' # options: bigram, columns, rows

# load your model
model_path = progress_paths['model_path']
model_data = parse_model_results(model_path)
model_data['labels'] = relabel_by_usage(model_data['labels'], count='usage')[0]

# Get modeled session uuids to compute group-mean transition graph for each group
label_group, uuids = get_trans_graph_groups(model_data)
group = list(set(label_group))
# compute transition matrices and usages for each group
print('Group(s):', ', '.join(group))
trans_mats, usages = get_group_trans_mats(model_data['labels'], label_group, group, max_syllables, normalize=normalize)

fig, ax = plt.subplots(1, len(group), figsize=(12, 8), sharex=False, sharey=True)
title_map = dict(bigram='Bigram', columns='Incoming', rows='Outgoing')

# max color threshold for graphs - set to any value 
color_lim = max([x.max() for x in trans_mats])

for i, g in enumerate(group):
    h = ax[i].imshow(trans_mats[i][:max_syllables,:max_syllables], cmap='cubehelix', vmax=color_lim)
    if i == 0:
        ax[i].set_ylabel('Incoming syllable')
    cb = fig.colorbar(h, ax=ax[i], fraction=0.046, pad=0.04)
    cb.set_label(f'{title_map[normalize]} transition probability')
    ax[i].set_xlabel('Outgoing syllable')
    ax[i].set_title(g)

# save transition matrix figure
os.makedirs(progress_paths['plot_path'], exist_ok=True)
for ext in ('pdf', 'png'):
    fig.savefig(join(progress_paths['plot_path'], f'{normalize}_tansition_matrix.{ext}'))
# Out:
# Group(s): SI_Regular, EE_Regular, LNB_Regular, LNB_Mom, NGH_Mom, NGH_Regular
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=15.0, sty…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=14.0, sty…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=10.0, sty…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=9.0, styl…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=2.0, styl…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=26.0, sty…

# %% [markdown]
# ## Export Transition Matrices and Usages
#
# You can export the transition matrices and usages to csv files for further analysis using the following cell.
#
# **Instructions:**
# - **Specify the path** to save the data in `save_path`. By default, it will save in the model folder.
# - **Run the cell** if you want to export the transition matrices and syllable usages as CSV files for analysis outside of this notebook.

# %%
import numpy as np
from os.path import join

save_path = progress_paths['model_session_path']

for group_name, tm, usage in zip(group, trans_mats, usages):
    out = join(save_path, f'{group_name}_{normalize}_transition_matrix.csv')
    np.savetxt(out, tm, delimiter=',')  # save TM as csv file
    out = join(save_path, f'{group_name}_syllable_counts.csv')
    np.savetxt(out, np.array(list(usage.items())), delimiter=',', header='syllable id,counts')  # save usage mapping as csv

# %% [markdown]
# ## Interactive Syllable Transition Graph Tool
# Transition matrices can also be visualized as directed graphs, where each node of the graph represents one syllable, and the directional edges represent transitions between syllables.
# The **node size** represents **syllable usage** and **edge thickness** represents the **syllable to syllable transition frequency**.
# This widget can also highlight the differences in transition frequencies between multiple experimental groups.
# You can find more information in the [wiki](https://github.com/dattalab/moseq2-app/wiki/MoSeq2-Analysis-Visualization-Notebook-Instructions#using-the-syllable-transition-graph-tool).
#
# **Instructions:**
# - **Run the following 2 cells**. The first cell changes how the widget is displayed (by removing scroll bars).
# - **Select the parameter(s)** from the dropdown menus to control the graph.
# - **Hover over the edges and nodes** to display syllable info. Edge colors represent the type of syllable-to-syllable transitions.
# **Note: Nodes outside the threshold will be hidden. The widget may take some time (5-10 seconds) to reload after changing the parameters. Be patient as the data loads.**
# - **Click the save icon in the toolbar on top of the figures** to save the figures as SVG in your default web image download folder.

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
from moseq2_app.main import interactive_transition_graph

# max_syllables is defined above
interactive_transition_graph(progress_paths, max_syllables=max_syllables, plot_vertically=True, load_parquet=True)
# Out:
# Syllable DataFrame not found. Creating new dataframe and computing syllable statistics...
# HBox(children=(FloatProgress(value=0.0, description='Creating MoSeq DataFrame', max=76.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=14.0, sty…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=9.0, styl…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=10.0, sty…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=2.0, styl…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=26.0, sty…
# HBox(children=(FloatProgress(value=0.0, description='Computing bigram transition probabilities', max=15.0, sty…
# Button(description='Clear Output', style=ButtonStyle(), tooltip='Close Cell Output')
# HBox(children=(VBox(children=(Dropdown(description='Graph Layout', layout=Layout(align_items='stretch', width=…
# Output()

# %% [markdown]
# ***
#
# # Notebook End
#
# # User Survey
#
# Please take some time to tell us your thoughts about this notebook:
# **[user feedback survey](https://forms.gle/S88jptAEs41mQjff7)**
