# %% [markdown]
# # Imports

# %%
import json
import os

# %% [markdown]
# # Metadata Location and Import

# %%
root = '/om2/user/rraju/data/moseq_data/session_20240321150325/metadata.json'

# %%
# Open and read the JSON file
with open(root, 'r') as file:
    data = json.load(file)

# Print the dictionary
print(data)
# Out:
# {'SubjectName': 'session_20240321150325', 'SessionName': 'session_20240321150325', 'NidaqChannels': 0, 'NidaqSamplingRate': 0.0, 'DepthResolution': [512, 424], 'ColorDataType': 'Byte[]', 'StartTime': ''}
